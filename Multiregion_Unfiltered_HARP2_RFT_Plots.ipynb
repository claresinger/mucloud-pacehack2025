# %%
import cartopy.crs as ccrs
import earthaccess
import matplotlib.pyplot as plt
import numpy as np
import xarray as xr
from tools import time_from_attr,open_L2_CLOUD_GPC,plot_hist
from matplotlib.colors import LogNorm
from scipy.stats import chi2
from collision_coalescence import CC_growth_rates_retrieval
import shapely.geometry as sgeom
import cartopy.feature as cfeature
from shapely.prepared import prep
import numpy as np
import time
from pathlib import Path
from scipy.spatial import cKDTree  # only needed for fallback remap

# %%
auth = earthaccess.login(persist=True)

# %%
def open_L2_CLOUD_GPC(path,bounding_box=(-170,-60,-120,-50)):
    """
    Args:
        path: a path to a dataset corresponding to one Level-2 granule
        bounding_box: optional argument of bounding box for region (defaults to Southern Ocean)
    Returns:
        the dataset restricted to the bounding_box region, with specific variables, and with the datetime added as time coord
    """
    dt = xr.open_datatree(path)
    ds = xr.merge(dt.to_dict().values())
    ds = time_from_attr(ds)
    ds = ds.set_coords(('latitude','longitude'))
    ds = ds[['cloud_bow_droplet_number_concentration_adiabatic',
             'cloud_bow_liquid_water_path','cloud_optical_thickness',
             'cloud_top_altitude','cloud_top_temperature','cloud_top_pressure',
             'cloud_liquid_index',
             'cloud_rft_droplet_effective_radius_mode_0','cloud_rft_droplet_effective_variance_mode_0', 'cloud_rft_mode_fraction_0',
             'cloud_rft_droplet_effective_radius_mode_1','cloud_rft_droplet_effective_variance_mode_1', 'cloud_rft_mode_fraction_1']]
    #anc_name = ds.aux_file
    #s3_uri   = f"s3://ob-cumulus-prod-public/{anc_name}"
    #ds_anc = xr.open_dataset(s3_uri, engine="h5netcdf",chunks="auto")
    
    W,S,E,N = bounding_box
    lat_mask = np.logical_and(ds.latitude<=N,ds.latitude>=S)
    lon_mask = np.logical_and(ds.longitude<=E,ds.longitude>=W)
    #land_mask = vec_is_over_land(ds.longitude,ds.latitude)
    mask = np.logical_and(lat_mask,lon_mask)#,land_mask)
    ds = ds.where(mask,drop=True)
    return(ds)

## Establish land surface mask
# Load land polygons at coarse resolution
land_geom = cfeature.NaturalEarthFeature('physical', 'land', '110m')
land_polygons = list(land_geom.geometries())
land = prep(sgeom.MultiPolygon(land_polygons))

def is_over_land(lat, lon):
    point = sgeom.Point(lon, lat)
    return land.contains(point)

# Vectorize for arrays
vec_is_over_land = np.vectorize(is_over_land)

# %%
import os, json, hashlib
import numpy as np
from pathlib import Path
import cartopy.feature as cfeature
import shapely
import shapely.geometry as sgeom
import shapely.ops as sops

CACHE_DIR = Path("landmask_cache")
CACHE_DIR.mkdir(exist_ok=True)

def _cache_path(bbox, res_deg, ne_res):
    key = json.dumps({"bbox": bbox, "res": float(res_deg), "ne": ne_res})
    h = hashlib.sha1(key.encode()).hexdigest()[:12]
    return CACHE_DIR / f"landmask_{h}_{res_deg}deg_{ne_res}.npz"

def _grid_for_box(w, s, e, n, res_deg):
    lat_vec = np.arange(s, n + res_deg, res_deg, dtype=np.float32)
    lon_vec = np.arange(w, e + res_deg, res_deg, dtype=np.float32)
    lon2d, lat2d = np.meshgrid(lon_vec, lat_vec)
    return lat_vec, lon_vec, lat2d, lon2d

def build_bbox_landmask(bbox, res_deg=0.1, ne_res="50m", use_cache=True):
    """
    Precompute a land mask over the bbox at 'res_deg' resolution.
    Returns: lat_vec [Ny], lon_vec [Nx], land_bool [Ny,Nx] (True=land)
    """
    W, S, E, N = bbox
    cache = _cache_path(bbox, res_deg, ne_res)
    if use_cache and cache.exists():
        z = np.load(cache)
        return z["lat_vec"], z["lon_vec"], z["land_bool"]

    # Load Natural Earth land polygons and union into one geometry
    land_feat = cfeature.NaturalEarthFeature("physical", "land", ne_res)
    land_union = sops.unary_union(list(land_feat.geometries()))

    # Handle dateline-crossing bbox by splitting into two boxes if needed
    boxes = [(W, S, E, N)] if W <= E else [(W, S, 180.0, N), (-180.0, S, E, N)]

    land_parts = []
    lat_parts, lon_parts = [], []

    for (w, s, e, n) in boxes:
        lat_vec, lon_vec, lat2d, lon2d = _grid_for_box(w, s, e, n, res_deg)

        bbox_poly = sgeom.Polygon([(w, s), (e, s), (e, n), (w, n)])

        # If bbox has no land at all → all False mask (fast exit)
        if land_union.disjoint(bbox_poly):
            land_bool = np.zeros(lon2d.shape, dtype=bool)
            lat_parts.append(lat_vec); lon_parts.append(lon_vec); land_parts.append(land_bool)
            continue

        # Intersect to reduce work when land fraction is small
        land_in_bbox = land_union.intersection(bbox_poly)

        # Optional micro-optimization: only compute inside the bounds of land∩bbox
        minx, miny, maxx, maxy = land_in_bbox.bounds
        dlat = float(np.abs(np.diff(lat_vec).mean())) if len(lat_vec) > 1 else res_deg
        dlon = float(np.abs(np.diff(lon_vec).mean())) if len(lon_vec) > 1 else res_deg
        i0 = max(0, int(np.floor((miny - lat_vec[0]) / dlat)))
        i1 = min(lat_vec.size, int(np.ceil((maxy - lat_vec[0]) / dlat)) + 1)
        j0 = max(0, int(np.floor((minx - lon_vec[0]) / dlon)))
        j1 = min(lon_vec.size, int(np.ceil((maxx - lon_vec[0]) / dlon)) + 1)

        land_bool = np.zeros(lon2d.shape, dtype=bool)  # default ocean
        sub_lon = lon2d[i0:i1, j0:j1]
        sub_lat = lat2d[i0:i1, j0:j1]

        try:
            # Shapely 2.x fast path (vectorized)
            pts = shapely.points(sub_lon.ravel(), sub_lat.ravel())
            inside = shapely.contains(land_in_bbox, pts).reshape(sub_lon.shape)
            land_bool[i0:i1, j0:j1] = inside
        except Exception:
            # Shapely 1.x fallback
            prepared = shapely.prepared.prep(land_in_bbox)
            land_bool[i0:i1, j0:j1] = np.vectorize(
                lambda x, y: prepared.contains(sgeom.Point(x, y))
            )(sub_lon, sub_lat)

        lat_parts.append(lat_vec); lon_parts.append(lon_vec); land_parts.append(land_bool)

    # If we split at the dateline, stitch along longitude (latitudes match)
    if len(boxes) == 1:
        lat_vec, lon_vec, land_bool = lat_parts[0], lon_parts[0], land_parts[0]
    else:
        lat_vec = lat_parts[0]
        lon_vec = np.concatenate((lon_parts[0], lon_parts[1]))
        land_bool = np.concatenate((land_parts[0], land_parts[1]), axis=1)

    if use_cache:
        np.savez_compressed(cache, lat_vec=lat_vec, lon_vec=lon_vec, land_bool=land_bool)

    return lat_vec, lon_vec, land_bool

def land_mask_lookup(lat, lon, lat_vec, lon_vec, land_bool):
    """
    Map swath lat/lon to the precomputed grid (nearest-neighbor).
    Returns boolean array aligned with 'lat'/'lon' shape. Assumes input points are within bbox.
    """
    lat = np.asarray(lat); lon = np.asarray(lon)
    dlat = float(np.abs(np.diff(lat_vec).mean())) if len(lat_vec) > 1 else 1.0
    dlon = float(np.abs(np.diff(lon_vec).mean())) if len(lon_vec) > 1 else 1.0

    ilat = np.clip(np.rint((lat - lat_vec[0]) / dlat).astype(int), 0, lat_vec.size - 1)
    ilon = np.clip(np.rint((lon - lon_vec[0]) / dlon).astype(int), 0, lon_vec.size - 1)
    return land_bool[ilat, ilon]

# %%
def gamma_dist_moments(re,ve):
    r2=re**2*(ve-1)*(2*ve-1)
    r3=re**3*(ve-1)*(2*ve-1)
    r4=re**4*(ve-1)*(2*ve-1)*(ve+1)
    return r2, r3, r4

def combine_moments(re1,ve1,mode_fraction1,re2,ve2,mode_fraction2):
    r2_1, r3_1, r4_1 = gamma_dist_moments(re1, ve1)
    r2_2, r3_2, r4_2 = gamma_dist_moments(re2, ve2)

    W_1 = mode_fraction1
    W_2 = mode_fraction2
    
    re_p = (W_1*r3_1 + W_2*r3_2) / (W_1*r2_1 + W_2*r2_2)
    ve_p = (W_1*(r4_1*r2_1) + W_2*(r4_2*r2_2)) / (W_1*r3_1 + W_2*r3_2)**2 - 1
    re_mean = W_1*re1 + W_2*re2
    ve_mean = W_1*ve1 + W_2*ve2

    return re_mean, ve_mean, re_p, ve_p

# %%
def gather_GPC(paths,bbox):
    er = []
    ev = []
    er_RFT = []
    ev_RFT = []
    er_RFT2 = []
    ev_RFT2 = []
    cdnc = []
    lwp = []
    cdnc2 = []
    lwp2 = []
    tau = []
    lindex = []
    cth = []
    ctp = []
    ctt = []
    lat = []
    lon = []
    lat2 = []
    lon2 = []
    modefrac=[]
    modefrac2=[]


    lat_vec, lon_vec, land_bool = build_bbox_landmask(bbox, res_deg=0.1, ne_res="50m")
    
    count = 0
    counterr = 0
    
    for p in paths:
        try: 
            ds = open_L2_CLOUD_GPC(p,bbox)
            across_dim = ds.latitude.dims[-1]  # last dim of lat/vars is across-track
            ds = ds.isel({across_dim: slice(0, 311)})  # drop columns > 310 up front
            # for each granule:
            # ... open ds, apply across-track cut & bbox crop ...
            is_land = land_mask_lookup(ds.latitude.data, ds.longitude.data, lat_vec, lon_vec, land_bool)
            ocean_mask = ~is_land.flatten()
            valid_mask = (~np.isnan(ds.cloud_rft_droplet_effective_radius_mode_0.data.flatten()) & ~np.isnan(ds.cloud_rft_droplet_effective_variance_mode_0.data.flatten()))        
            mask = ocean_mask & valid_mask
            valid_mask2 = (~np.isnan(ds.cloud_rft_droplet_effective_radius_mode_1.data.flatten()) & ~np.isnan(ds.cloud_rft_droplet_effective_variance_mode_1.data.flatten()))        
            mask2 = ocean_mask & valid_mask2
            
            #er = np.concatenate((er,ds.cloud_bow_droplet_effective_radius.data.flatten()[mask]))
            #ev = np.concatenate((ev,ds.cloud_bow_droplet_effective_variance.data.flatten()[mask]))
            er_RFT = np.concatenate((er_RFT,ds.cloud_rft_droplet_effective_radius_mode_0.data.flatten()[mask]))
            ev_RFT = np.concatenate((ev_RFT,ds.cloud_rft_droplet_effective_variance_mode_0.data.flatten()[mask]))
            modefrac = np.concatenate((modefrac,ds.cloud_rft_mode_fraction_0.data.flatten()[mask]))

            er_RFT2 = np.concatenate((er_RFT2,ds.cloud_rft_droplet_effective_radius_mode_1.data.flatten()[mask2]))
            ev_RFT2 = np.concatenate((ev_RFT2,ds.cloud_rft_droplet_effective_variance_mode_1.data.flatten()[mask2]))
            modefrac2 = np.concatenate((modefrac2,ds.cloud_rft_mode_fraction_1.data.flatten()[mask2]))
                
            #re_mean, ve_mean, re_p, ve_p = combine_moments(ds.cloud_rft_droplet_effective_radius_mode_0.data.flatten()[mask],
            #                                               ds.cloud_rft_droplet_effective_variance_mode_0.data.flatten()[mask],
            #                                               ds.cloud_rft_mode_fraction_0.data.flatten()[mask],
            #                                               ds.cloud_rft_droplet_effective_radius_mode_1.data.flatten()[mask],
            #                                               ds.cloud_rft_droplet_effective_variance_mode_1.data.flatten()[mask],
            #                                               ds.cloud_rft_mode_fraction_1.data.flatten()[mask])

            #er = np.concatenate((er,re_mean))
            #ev = np.concatenate((ev,ve_mean))
            #rmse_bow =  np.concatenate((rmse_bow,ds.cloud_bow_rms.data.flatten()[mask]))
            #corr_bow =  np.concatenate((corr_bow,ds.cloud_bow_fit_correlation.data.flatten()[mask]))    
            cdnc = np.concatenate((cdnc,ds.cloud_bow_droplet_number_concentration_adiabatic.data.flatten()[mask]))
            lwp = np.concatenate((lwp,ds.cloud_bow_liquid_water_path.data.flatten()[mask]))
            tau = np.concatenate((tau,ds.cloud_optical_thickness.data.flatten()[mask]))
            cdnc2 = np.concatenate((cdnc2,ds.cloud_bow_droplet_number_concentration_adiabatic.data.flatten()[mask2]))
            lwp2 = np.concatenate((lwp2,ds.cloud_bow_liquid_water_path.data.flatten()[mask2]))
            lindex = np.concatenate((lindex,ds.cloud_liquid_index.data.flatten()[mask]))
            #WF = np.concatenate((WF,ds.waterfraction.data.flatten()[mask]))
            #CF = np.concatenate((CF,ds.water_cloud_fraction.data.flatten()[mask]))
            
            lat = np.concatenate((lat,ds.latitude.data.flatten()[mask]))
            lon = np.concatenate((lon,ds.longitude.data.flatten()[mask]))
            lat2 = np.concatenate((lat2,ds.latitude.data.flatten()[mask2]))
            lon2 = np.concatenate((lon2,ds.longitude.data.flatten()[mask2]))
            print(ds.aux_file)
            del(ds)
        except:
            print('I had an error', count)
            #break
            
        count += 1
    
    #CC=CC_growth_rates_retrieval(er,ev,tau,ctt,ctp,Cw=0.0020, fad=0.7, Qext = 2.0)
    return er_RFT, ev_RFT, modefrac, er_RFT2, ev_RFT2, modefrac2, cdnc, lwp, cdnc2, lwp2, tau, lindex, lat, lon, lat2, lon2

# %%
def plot_GPC_LWP_Nd_hist(title, er_RFT, ev_RFT, modefrac, er_RFT2, ev_RFT2, modefrac2, cdnc, lwp, cdnc2, lwp2, tau, lindex, lat, lon, lat2, lon2):
    xbins = np.logspace(np.log10(5),np.log10(1100),50) # <- make a range from 10**xmin to 10**xmax ## Selected to sample SEP 95%
    ybins = np.logspace(np.log10(5),np.log10(500),50) # <- make a range from 10**ymin to 10**ymax ## Selected to sample SEP 95%
    counts, xedge, yedge = np.histogram2d(cdnc, lwp, bins=(xbins, ybins))
    counts2, xedge, yedge = np.histogram2d(cdnc2, lwp2, bins=(xbins, ybins))

    #sum_re,   _, _ = np.histogram2d(cdnc, lwp, bins=(xbins, ybins), weights=er)
    #sum_ve,   _, _ = np.histogram2d(cdnc, lwp, bins=(xbins, ybins), weights=ev)
    sum_re_RFT,   _, _ = np.histogram2d(cdnc, lwp, bins=(xbins, ybins), weights=er_RFT)
    sum_ve_RFT,   _, _ = np.histogram2d(cdnc, lwp, bins=(xbins, ybins), weights=ev_RFT)
    sum_modefrac,   _, _ = np.histogram2d(cdnc, lwp, bins=(xbins, ybins), weights=modefrac)    
    sum_re_RFT2,   _, _ = np.histogram2d(cdnc2, lwp2, bins=(xbins, ybins), weights=er_RFT2)
    sum_ve_RFT2,   _, _ = np.histogram2d(cdnc2, lwp2, bins=(xbins, ybins), weights=ev_RFT2)
    sum_modefrac2,   _, _ = np.histogram2d(cdnc2, lwp2, bins=(xbins, ybins), weights=modefrac2)    
    #sum_tau,   _, _ = np.histogram2d(cdnc, lwp, bins=(xbins, ybins), weights=tau)
    sum_tau_log,   _, _ = np.histogram2d(cdnc, lwp, bins=(xbins, ybins), weights=np.log10(tau))
    #sum_CTH,   _, _ = np.histogram2d(cdnc, lwp, bins=(xbins, ybins), weights=cth)
    sum_lindex,   _, _ = np.histogram2d(cdnc, lwp, bins=(xbins, ybins), weights=lindex)
    sum_lon,   _, _ = np.histogram2d(cdnc, lwp, bins=(xbins, ybins), weights=np.abs(lon))
    sum_lat,   _, _ = np.histogram2d(cdnc, lwp, bins=(xbins, ybins), weights=np.abs(lat))
    sum_thin_frac,   _, _ = np.histogram2d(cdnc, lwp, bins=(xbins, ybins), weights=(tau<=3))
    #sum_CC_AU,   _, _ = np.histogram2d(cdnc, lwp, bins=(xbins, ybins), weights=np.log10(-CC[0].magnitude))
    #sum_CC_SC,   _, _ = np.histogram2d(cdnc, lwp, bins=(xbins, ybins), weights=np.log10(-CC[1].magnitude))
    #sum_rmse_bow,   _, _ = np.histogram2d(cdnc, lwp, bins=(xbins, ybins), weights=rmse_bow)
    #sum_corr_bow,   _, _ = np.histogram2d(cdnc, lwp, bins=(xbins, ybins), weights=corr_bow)
    
    
    # Mean and (optional) standard deviation of z per bin
    with np.errstate(divide='ignore', invalid='ignore'):
        #mean_re = sum_re / counts
        #mean_ve = sum_ve / counts
        mean_re_mode0 = sum_re_RFT / counts
        mean_ve_mode0 = sum_ve_RFT / counts
        mean_modefrac0 = sum_modefrac / counts
        mean_re_mode1 = sum_re_RFT2 / counts2
        mean_ve_mode1 = sum_ve_RFT2 / counts2
        mean_modefrac1 = sum_modefrac2 / counts2
        #mean_tau = sum_tau / counts
        mean_tau_log = 10**(sum_tau_log / counts)
        #mean_CTH = sum_CTH / counts
        mean_lindex = sum_lindex / counts
        mean_thin_frac = sum_thin_frac / counts
        mean_lon = sum_lon / counts
        mean_lat = sum_lat / counts
        #mean_CC_AU = 10**(sum_CC_AU / counts)
        #mean_CC_SC = 10**(sum_CC_SC / counts)
        #mean_rmse_bow = sum_rmse_bow / counts    
        #mean_corr_bow = sum_corr_bow / counts
        
    counts_plt=counts/np.sum(counts)
    counts_plt=counts_plt.T
    counts_plt[counts_plt == 0] = np.nan
    
    h_norm = counts/counts.sum(axis=1,keepdims=True)
    h_norm=np.transpose(h_norm)
    h_norm[h_norm == 0] = np.nan
    
    hist_sorted = np.sort(counts.ravel())
    cumulative_sum = np.cumsum(hist_sorted)
    total_count = cumulative_sum[-1]
    #hist_levels=np.zeros(3,dtype=np.float64)
    #for i in range(3):
    #    prob = chi2.cdf([3**2, 2**2, 1**2], df=2)
        
    prob=0.95
    hist_levels = hist_sorted[cumulative_sum >= total_count * (1 - prob)][0]
    
    ##############
    fig,ax = plt.subplots(2,2,figsize=(11, 8))
    plt.suptitle(title)
    
    cmap=plt.colormaps['turbo']
    cmap.set_bad('gray', alpha=1.0)
    titles={}
    ims={}
    
    titles[(0,0)] = 'Histogram ($N_d$ bin norm)'
    ims[(0,0)] = ax[0,0].pcolormesh(xedge,yedge,h_norm,cmap=cmap,vmax=0.06)#,norm=LogNorm(vmin=np.nanmin(h_norm), vmax=0.12))
    titles[(0,1)] = 'Mean $r_e$ RFT Mode0 ($N_d$ bin norm)'
    ims[(0,1)] = ax[0,1].pcolormesh(xedge,yedge,mean_re_mode0.T,cmap=cmap,vmax=40)#,norm=LogNorm(vmin=np.nanmin(h_norm), vmax=0.12))
    titles[(1,0)] = 'Mean Mode Fraction ($N_d$ bin norm)'
    ims[(1,0)] = ax[1,0].pcolormesh(xedge,yedge,mean_modefrac0.T,cmap=cmap)#,norm=LogNorm(vmin=np.nanmin(h_norm), vmax=0.12))
    titles[(1,1)] = 'Mean $v_e$  RFT Mode0 ($N_d$ bin norm)'
    ims[(1,1)] = ax[1,1].pcolormesh(xedge,yedge,mean_ve_mode0.T,cmap=cmap,vmax=0.25)#,norm=LogNorm(vmin=np.nanmin(h_norm), vmax=0.12))
    
    for i in range(2):
        for j in range(2):
            ax[i,j].plot([15,100], [10,300], color='black', linewidth=2, label='$r_e=15\,\mathrm{\mum}$')
            ax[i,j].contour(xedge[:-1], yedge[:-1], counts.T, levels=[hist_levels], colors="white", linestyles="--", linewidths=1)# 95% interval
            #ax[i,j].contour(xedge[:-1], yedge[:-1], counts, levels=hist_levels[1], colors="white", linestyles="--", linewidths=2)
    
            ax[i,j].set_yscale('log')
            ax[i,j].set_xscale('log')
            ax[i,j].set_xlabel("$N_d$ [cm$^{-3}$]")
            ax[i,j].set_ylabel("LWP [g m$^{-2}$]")
            ax[i,j].set_title(titles[i,j])
            ax[i,j].set_aspect('equal', adjustable='box')
            fig.colorbar(ims[(i,j)],ax=ax[i,j])
    plt.tight_layout()
    plt.show()
    
    
    #####################
    fig,ax = plt.subplots(2,2,figsize=(11, 8))
    plt.suptitle(f'{title} adv Diagnostics')
    
    cmap=plt.colormaps['turbo']
    cmap.set_bad('gray', alpha=1.0)
    titles={}
    ims={}
    
    titles[(0,0)] = 'Histogram ($N_d$ bin norm)'
    ims[(0,0)] = ax[0,0].pcolormesh(xedge,yedge,h_norm,cmap=cmap,vmax=0.06)#,norm=LogNorm(vmin=np.nanmin(h_norm), vmax=0.12))
    titles[(0,1)] = 'Mean re combined RFT ($N_d$ bin norm)'
    ims[(0,1)] = ax[0,1].pcolormesh(xedge,yedge,mean_re_mode1.T,cmap=cmap,vmax=40)#,norm=LogNorm(vmin=np.nanmin(h_norm), vmax=0.12))
    titles[(1,0)] = 'Mean modefraction RFT ($N_d$ bin norm)'
    ims[(1,0)] = ax[1,0].pcolormesh(xedge,yedge,mean_modefrac1.T,cmap=cmap)#,norm=LogNorm(vmin=np.nanmin(h_norm), vmax=0.12))
    titles[(1,1)] = 'Mean ve combined RFT ($N_d$ bin norm)'
    ims[(1,1)] = ax[1,1].pcolormesh(xedge,yedge,mean_ve_mode1.T,cmap=cmap)#,norm=LogNorm(vmin=np.nanmin(h_norm), vmax=0.12))
    
    for i in range(2):
        for j in range(2):
            ax[i,j].plot([15,100], [10,300], color='black', linewidth=2, label='$r_e=15\,\mathrm{\mum}$')
            ax[i,j].contour(xedge[:-1], yedge[:-1], counts.T, levels=[hist_levels], colors="white", linestyles="--", linewidths=1)# 95% interval
            #ax[i,j].contour(xedge[:-1], yedge[:-1], counts, levels=hist_levels[1], colors="white", linestyles="--", linewidths=2)
    
            ax[i,j].set_yscale('log')
            ax[i,j].set_xscale('log')
            ax[i,j].set_xlabel("$N_d$ [cm$^{-3}$]")
            ax[i,j].set_ylabel("LWP [g m$^{-2}$]")
            ax[i,j].set_title(titles[i,j])
            ax[i,j].set_aspect('equal', adjustable='box')
            fig.colorbar(ims[(i,j)],ax=ax[i,j])
    
    
    plt.tight_layout()
    plt.show()
    
    ##############
    fig,ax = plt.subplots(3,2,figsize=(11, 8))
    cmap=plt.colormaps['turbo']
    cmap.set_bad('gray', alpha=1.0)
    plt.suptitle(f'{title} Additional')
    
    titles={}
    ims={}
    
    titles[(0,0)] = 'Mean modefrac ($N_d$ bin norm)'
    ims[(0,0)] = ax[0,0].pcolormesh(xedge,yedge,mean_modefrac0.T,cmap=cmap)#norm=LogNorm(vmin=np.nanmin(np.stack([mean_CC_AU,mean_CC_SC])), vmax=np.nanmax(np.stack([mean_CC_AU,mean_CC_SC]))))
    titles[(0,1)] = 'Mean combined re RFT ($N_d$ bin norm)'
    ims[(0,1)] = ax[0,1].pcolormesh(xedge,yedge,(mean_modefrac0*mean_ve_mode0+mean_modefrac1*mean_ve_mode1).T,cmap=cmap,vmax=40)#,norm=LogNorm(vmin=np.nanmin(h_norm), vmax=0.12))
    titles[(1,0)] = 'Mean combined ve RFT ($N_d$ bin norm)'
    ims[(1,0)] = ax[1,0].pcolormesh(xedge,yedge,(mean_modefrac0*mean_ve_mode0+mean_modefrac1*mean_ve_mode1).T,cmap=cmap)
    titles[(1,1)] = 'Mean __ ($N_d$ bin norm)'
    ims[(1,1)] = ax[1,1].pcolormesh(xedge,yedge,mean_modefrac1.T,cmap=cmap)#,vmax=0.25)#,norm=LogNorm(vmin=np.nanmin(h_norm), vmax=0.12))
    titles[(2,0)] = 'Mean ___ ($N_d$ bin norm)'
    ims[(2,0)] = ax[2,0].pcolormesh(xedge,yedge,mean_modefrac1.T,cmap=cmap)
    titles[(2,1)] = 'Mean Liq Index ($N_d$ bin norm)'
    ims[(2,1)] = ax[2,1].pcolormesh(xedge,yedge,mean_lindex.T,cmap=cmap)#,vmax=0.25)#,norm=LogNorm(vmin=np.nanmin(h_norm), vmax=0.12))
    
    
    for i in range(3):
        for j in range(2):
            ax[i,j].plot([15,100], [10,300], color='black', linestyle='--', linewidth=2, label='$r_e=15\,\mathrm{\mum}$')
            ax[i,j].contour(xedge[:-1], yedge[:-1], counts.T, levels=[hist_levels], colors="white", linestyles="--", linewidths=1)# 95% interval
            #ax[i,j].contour(xedge[:-1], yedge[:-1], counts, levels=hist_levels[1], colors="white", linestyles="--", linewidths=2)
    
            ax[i,j].set_yscale('log')
            ax[i,j].set_xscale('log')
            ax[i,j].set_xlabel("$N_d$ [cm$^{-3}$]")
            ax[i,j].set_ylabel("LWP [g m$^{-2}$]")
            ax[i,j].set_title(titles[i,j])
            ax[i,j].set_aspect('equal', adjustable='box')
            fig.colorbar(ims[(i,j)],ax=ax[i,j])
    
    
    
    plt.tight_layout()
    plt.show()

# %%
def plot_GPC_L3maps(title, er_RFT, ev_RFT, modefrac, er_RFT2, ev_RFT2, modefrac2, cdnc, lwp, cdnc2, lwp2, tau, lindex, lat, lon, lat2, lon2):
    xbins = np.linspace(np.nanmin(lon),np.nanmax(lon),75) 
    ybins = np.linspace(np.nanmin(lat),np.nanmax(lat),75) 
    
    counts, xedge, yedge = np.histogram2d(lon, lat, bins=(xbins, ybins))
    counts2, xedge, yedge = np.histogram2d(lon2, lat2, bins=(xbins, ybins))

    #sum_re,   _, _ = np.histogram2d(lon, lat, bins=(xbins, ybins), weights=er)
    #sum_ve,   _, _ = np.histogram2d(lon, lat, bins=(xbins, ybins), weights=ev)
    sum_re_RFT,   _, _ = np.histogram2d(lon, lat, bins=(xbins, ybins), weights=er_RFT)
    sum_ve_RFT,   _, _ = np.histogram2d(lon, lat, bins=(xbins, ybins), weights=ev_RFT)
    sum_modefrac,   _, _ = np.histogram2d(lon, lat, bins=(xbins, ybins), weights=modefrac)    
    sum_re_RFT2,   _, _ = np.histogram2d(lon2, lat2, bins=(xbins, ybins), weights=er_RFT2)
    sum_ve_RFT2,   _, _ = np.histogram2d(lon2, lat2, bins=(xbins, ybins), weights=ev_RFT2)
    sum_modefrac2,   _, _ = np.histogram2d(lon2, lat2, bins=(xbins, ybins), weights=modefrac2)    
    #sum_tau,   _, _ = np.histogram2d(lon, lat, bins=(xbins, ybins), weights=tau)
    sum_tau_log,   _, _ = np.histogram2d(lon, lat, bins=(xbins, ybins), weights=np.log10(tau))
    sum_LWP,   _, _ = np.histogram2d(lon, lat, bins=(xbins, ybins), weights=lwp)
    sum_Nd,   _, _ = np.histogram2d(lon, lat, bins=(xbins, ybins), weights=cdnc)
    #sum_CTH,   _, _ = np.histogram2d(lon, lat, bins=(xbins, ybins), weights=cth)
    sum_lindex,   _, _ = np.histogram2d(lon, lat, bins=(xbins, ybins), weights=lindex)
    sum_lon,   _, _ = np.histogram2d(lon, lat, bins=(xbins, ybins), weights=np.abs(lon))
    sum_lat,   _, _ = np.histogram2d(lon, lat, bins=(xbins, ybins), weights=np.abs(lat))
    sum_thin_frac,   _, _ = np.histogram2d(lon, lat, bins=(xbins, ybins), weights=(tau<=3))
    #sum_CC_AU,   _, _ = np.histogram2d(lon, lat, bins=(xbins, ybins), weights=np.log10(-CC[0].magnitude))
    #sum_CC_SC,   _, _ = np.histogram2d(lon, lat, bins=(xbins, ybins), weights=np.log10(-CC[1].magnitude))
    #sum_rmse_bow,   _, _ = np.histogram2d(lon, lat, bins=(xbins, ybins), weights=rmse_bow)
    #sum_corr_bow,   _, _ = np.histogram2d(lon, lat, bins=(xbins, ybins), weights=corr_bow)
    
    
    # Mean and (optional) standard deviation of z per bin
    with np.errstate(divide='ignore', invalid='ignore'):
        #mean_re = sum_re / counts
        #mean_ve = sum_ve / counts
        mean_re_mode0 = sum_re_RFT / counts
        mean_ve_mode0 = sum_ve_RFT / counts
        mean_modefrac0 = sum_modefrac / counts
        mean_re_mode1 = sum_re_RFT2 / counts2
        mean_ve_mode1 = sum_ve_RFT2 / counts2
        mean_modefrac1 = sum_modefrac2 / counts2
        #mean_tau = sum_tau / counts
        mean_tau_log = 10**(sum_tau_log / counts)
        mean_LWP = sum_LWP / counts
        mean_Nd = sum_Nd / counts
        #mean_CTH = sum_CTH / counts
        mean_lindex = sum_lindex / counts
        mean_thin_frac = sum_thin_frac / counts
        mean_lon = sum_lon / counts
        mean_lat = sum_lat / counts
        #mean_CC_AU = 10**(sum_CC_AU / counts)
        #mean_CC_SC = 10**(sum_CC_SC / counts)
        #mean_rmse_bow = sum_rmse_bow / counts    
        #mean_corr_bow = sum_corr_bow / counts
    
    
    xbc=(xbins[0:-1]+xbins[1:])/2 #bin centers not edges
    ybc=(ybins[0:-1]+ybins[1:])/2
    [lon_g,lat_g]=np.meshgrid(xbc,ybc)
    
    LM = ~vec_is_over_land(lat_g,lon_g)  # True = land, False = ocean
    plt.pcolormesh(LM)
    plt.show()
    
    fig,ax = plt.subplots(3,2,figsize=(11, 8))
    cmap=plt.colormaps['turbo']
    cmap.set_bad('gray', alpha=1.0)
    plt.suptitle(title)
    
    titles={}
    ims={}
    
    titles[(0,0)] = 'Mean CER RFT0'
    ims[(0,0)] = ax[0,0].pcolormesh(xedge,yedge,np.where(LM, mean_re_mode0.T, np.nan),cmap=cmap,vmax=20)#norm=LogNorm(vmin=np.nanmin(np.stack([mean_CC_AU,mean_CC_SC])), vmax=np.nanmax(np.stack([mean_CC_AU,mean_CC_SC]))))
    titles[(0,1)] = 'Mean Modefrac0'
    ims[(0,1)] = ax[0,1].pcolormesh(xedge,yedge,np.where(LM, mean_modefrac0.T, np.nan),cmap=cmap)#,norm=LogNorm(vmin=np.nanmin(h_norm), vmax=0.12))
    titles[(1,0)] = 'Mean CEV RFT0'
    ims[(1,0)] = ax[1,0].pcolormesh(xedge,yedge,np.where(LM, mean_ve_mode0.T, np.nan),cmap=cmap,vmax=0.25)
    titles[(1,1)] = 'Thin CF (COT<3)'
    ims[(1,1)] = ax[1,1].pcolormesh(xedge,yedge,np.where(LM, mean_thin_frac.T, np.nan),cmap=cmap)#,vmax=0.25)#,norm=LogNorm(vmin=np.nanmin(h_norm), vmax=0.12))
    titles[(2,0)] = 'Mean CER RFT1'
    ims[(2,0)] = ax[2,0].pcolormesh(xedge,yedge,np.where(LM, mean_re_mode1.T, np.nan),cmap=cmap,vmax=20)
    titles[(2,1)] = 'Mean CEV RFT1'
    ims[(2,1)] = ax[2,1].pcolormesh(xedge,yedge,np.where(LM, mean_ve_mode1.T, np.nan),cmap=cmap,vmax=0.25)#,norm=LogNorm(vmin=np.nanmin(h_norm), vmax=0.12))
    
    
    for i in range(3):
        for j in range(2):
            #ax[i,j].plot([15,100], [10,300], color='black', linestyle='--', linewidth=2, label='$r_e=15\,\mathrm{\mum}$')
            #ax[i,j].contour(xedge[:-1], yedge[:-1], counts.T, levels=[hist_levels], colors="white", linestyles="--", linewidths=1)# 95% interval
            #ax[i,j].contour(xedge[:-1], yedge[:-1], counts, levels=hist_levels[1], colors="white", linestyles="--", linewidths=2)
    
            #ax[i,j].set_yscale('log')
            #ax[i,j].set_xscale('log')
            ax[i,j].set_xlabel("Longitude")
            ax[i,j].set_ylabel("Latitude")
            ax[i,j].set_title(titles[i,j])
            ax[i,j].set_aspect('equal', adjustable='box')
            fig.colorbar(ims[(i,j)],ax=ax[i,j])
    
    plt.tight_layout()
    plt.show()
    
    fig,ax = plt.subplots(3,2,figsize=(11, 8))
    cmap=plt.colormaps['turbo']
    cmap.set_bad('gray', alpha=1.0)
    plt.suptitle(title)
    
    titles={}
    ims={}
    
    titles[(0,0)] = 'Mean CER'
    ims[(0,0)] = ax[0,0].pcolormesh(xedge,yedge,np.where(LM, (mean_modefrac0*mean_re_mode0+mean_modefrac1*mean_re_mode1).T, np.nan),cmap=cmap,vmax=20)#norm=LogNorm(vmin=np.nanmin(np.stack([mean_CC_AU,mean_CC_SC])), vmax=np.nanmax(np.stack([mean_CC_AU,mean_CC_SC]))))
    titles[(0,1)] = 'Mean CEV'
    ims[(0,1)] = ax[0,1].pcolormesh(xedge,yedge,np.where(LM, (mean_modefrac0*mean_ve_mode0+mean_modefrac1*mean_ve_mode1).T, np.nan),cmap=cmap,vmax=0.25)#,norm=LogNorm(vmin=np.nanmin(h_norm), vmax=0.12))
    titles[(1,0)] = 'Mean Liquid Index'
    ims[(1,0)] = ax[1,0].pcolormesh(xedge,yedge,np.where(LM, mean_lindex.T, np.nan),cmap=cmap)
    titles[(1,1)] = 'Thin CF (COT<3)'
    ims[(1,1)] = ax[1,1].pcolormesh(xedge,yedge,np.where(LM, mean_thin_frac.T, np.nan),cmap=cmap)#,vmax=0.25)#,norm=LogNorm(vmin=np.nanmin(h_norm), vmax=0.12))
    titles[(2,0)] = 'Sum of Mean modefrac0 and modefrac1'
    ims[(2,0)] = ax[2,0].pcolormesh(xedge,yedge,np.where(LM, mean_modefrac0.T+mean_modefrac1.T, np.nan),cmap=cmap)
    titles[(2,1)] = 'Mean modefrac1'
    ims[(2,1)] = ax[2,1].pcolormesh(xedge,yedge,np.where(LM, mean_modefrac1.T, np.nan),cmap=cmap)#,vmax=0.25)#,norm=LogNorm(vmin=np.nanmin(h_norm), vmax=0.12))
    
    
    for i in range(3):
        for j in range(2):
            #ax[i,j].plot([15,100], [10,300], color='black', linestyle='--', linewidth=2, label='$r_e=15\,\mathrm{\mum}$')
            #ax[i,j].contour(xedge[:-1], yedge[:-1], counts.T, levels=[hist_levels], colors="white", linestyles="--", linewidths=1)# 95% interval
            #ax[i,j].contour(xedge[:-1], yedge[:-1], counts, levels=hist_levels[1], colors="white", linestyles="--", linewidths=2)
    
            #ax[i,j].set_yscale('log')
            #ax[i,j].set_xscale('log')
            ax[i,j].set_xlabel("Longitude")
            ax[i,j].set_ylabel("Latitude")
            ax[i,j].set_title(titles[i,j])
            ax[i,j].set_aspect('equal', adjustable='box')
            fig.colorbar(ims[(i,j)],ax=ax[i,j])
    
    plt.tight_layout()
    plt.show()

# %%
import numpy as np
import pandas as pd
from typing import Optional, Dict

_NORMAL_MAD = 1.4826  # consistency factor so MAD ~ std for a normal

def _robust_groupwise_z(x: np.ndarray,
                        group: Optional[np.ndarray] = None) -> np.ndarray:
    """
    Robust z-scores computed within groups using median/MAD.
    NaNs in x are preserved. Group can be None (single group) or any array-like
    of same shape (e.g., month index, geometry bin).
    """
    x = np.asarray(x, dtype=float)
    z = np.full_like(x, np.nan, dtype=float)

    mask = np.isfinite(x)
    if group is None:
        xi = x[mask]
        if xi.size == 0:
            return z
        med = np.median(xi)
        mad = np.median(np.abs(xi - med))
        scale = _NORMAL_MAD * mad if mad > 0 else np.nan
        z[mask] = (xi - med) / (scale if np.isfinite(scale) and scale != 0 else 1.0)
        return z

    # groupwise
    g = np.asarray(group)
    if g.shape != x.shape:
        raise ValueError("group must have the same shape as x")
    # Use pandas grouping on the finite subset for speed and categorical handling
    s_x = pd.Series(x[mask])
    s_g = pd.Series(g[mask]).astype("category")

    med = s_x.groupby(s_g).transform("median")
    mad = (s_x - med).abs().groupby(s_g).transform("median")
    scale = _NORMAL_MAD * mad.replace(0.0, np.nan)
    z_vals = (s_x - med) / scale
    # Fallback where scale is zero/NaN: treat as zero-variance group
    z_vals = z_vals.fillna(0.0)

    z[mask] = z_vals.to_numpy()
    return z


def build_indices(re_cb: Optional[np.ndarray],
                  r0: np.ndarray, f0: np.ndarray,
                  r1: np.ndarray, f1: np.ndarray,
                  stratifier: Optional[np.ndarray] = None,
                  phi: Optional[np.ndarray] = None
                  ) -> Dict[str, np.ndarray]:
    """
    Build composite indices for precipitation (CCI) and entrainment (EI).

    Parameters
    ----------
    re_cb : Cloudbow effective radius (N,) or None.
            If None, you must provide `phi` (RFT rainbow phase proxy for mean size).
    r0, f0 : Mode-0 (dominant) radius and fraction (N,)
    r1, f1 : Mode-1 (secondary) radius and fraction (N,)
    stratifier : optional (N,) array to compute robust z-scores within groups
                 (e.g., month, geometry bin). If None, uses a single group.
    phi : optional (N,) RFT phase (monotonic proxy for mean size), used if re_cb is None.

    Returns
    -------
    dict with:
      CCI, EI, z_re (or z_phi), z_fL, z_fS, rL, rS, fL, fS  (all np.ndarray, shape (N,))
    """
    r0 = np.asarray(r0, dtype=float)
    r1 = np.asarray(r1, dtype=float)
    f0 = np.asarray(f0, dtype=float)
    f1 = np.asarray(f1, dtype=float)

    if re_cb is None and phi is None:
        raise ValueError("Provide either re_cb or phi (RFT phase).")

    # Order modes by radius per-sample
    rL = np.maximum(r0, r1)
    rS = np.minimum(r0, r1)
    # fraction for the larger-mode: pick f0 where r0>=r1, else f1
    pick_f0 = (r0 >= r1)
    fL = np.where(pick_f0, f0, f1)
    # fraction for smaller mode: total minus larger (more robust than 1-fL if f0+f1!=1)
    fS = (f0 + f1) - fL

    # Standardize within groups
    if re_cb is not None:
        z_re = _robust_groupwise_z(np.asarray(re_cb, dtype=float), stratifier)
        z_size = z_re
    else:
        z_phi = _robust_groupwise_z(np.asarray(phi, dtype=float), stratifier)
        z_size = z_phi

    z_fL = _robust_groupwise_z(fL, stratifier)
    z_fS = _robust_groupwise_z(fS, stratifier)

    # Composite indices (unit weights by default)
    CCI = z_size + z_fL - z_fS          # Coalescence/precipitation index
    EI  = z_fS  - z_size                # Entrainment/mixing index

    out = {
        "CCI": CCI,
        "EI": EI,
        "z_re_or_phi": z_size,          # whichever was used
        "z_fL": z_fL,
        "z_fS": z_fS,
        "rL": rL, "rS": rS,
        "fL": fL, "fS": fS
    }
    return out

# %%
def _nn_remap_to_target_grid(target_lat, target_lon, src_lat, src_lon, src_da):
    """Nearest-neighbor remap src_da (2D) onto target grid (2D). Returns an xr.DataArray."""
    pts_src = np.column_stack([src_lat.ravel(), src_lon.ravel()])
    pts_tgt = np.column_stack([target_lat.ravel(), target_lon.ravel()])
    tree = cKDTree(pts_src)
    _, idx = tree.query(pts_tgt, k=1)
    data = src_da.values.ravel()[idx].reshape(target_lat.shape)
    return xr.DataArray(
        data,
        dims=target_lat.dims,
        coords={target_lat.dims[0]: target_lat.coords[target_lat.dims[0]],
                target_lat.dims[1]: target_lat.coords[target_lat.dims[1]]},
        name=src_da.name,
        attrs=src_da.attrs
    )

def open_L2_CLOUD_GPC_wAUX(path, bounding_box=(-170,-60,-120,-50), across_max=310):
    """
    Returns the HARP-2 GPC dataset cropped to bbox & across_max, with AUX vars
    (water_cloud_fraction, waterfraction) merged on the same grid.
    """
    # --- open L2 (HARP-2 GPC)
    dt = xr.open_datatree(path)
    ds = xr.merge(dt.to_dict().values())
    dt.close()

    # coords & time
    ds = ds.set_coords(("latitude","longitude"))
    if "time" not in ds.coords:  # if your helper adds time, call it here if needed
        pass

    # keep only needed vars
    keep = [
        "cloud_bow_droplet_effective_radius",
        "cloud_bow_droplet_effective_variance",
        "cloud_bow_droplet_number_concentration_adiabatic",
        "cloud_bow_liquid_water_path","cloud_optical_thickness",
        "cloud_top_altitude","cloud_top_temperature","cloud_top_pressure",
        "cloud_liquid_index","cloud_bow_rms","cloud_bow_fit_correlation",
        "cloud_rft_droplet_effective_radius_mode_0","cloud_rft_droplet_effective_variance_mode_0",
        "latitude","longitude"
    ]
    ds = ds[keep]

    # harmonize dims
    along_dim = "bins_along_track"
    across_dim = "bins_across_track"

    # across-track cut (keep 0..across_max inclusive)
    ds = ds.isel({across_dim: slice(0, across_max+1)})

    # --- download + open AUX (OCI L1C ANC) from OBPG
    anc_name = str(ds.attrs["aux_file"]) if "aux_file" in ds.attrs else str(ds.aux_file)
    url = f"https://oceandata.sci.gsfc.nasa.gov/ob/getfile/{anc_name}"
    out_dir = Path("data"); out_dir.mkdir(exist_ok=True)
    out_path = out_dir / anc_name

    fs = earthaccess.get_fsspec_https_session()  # uses your EDL creds
    fs.get(url, out_dir.as_posix())              # saves to data/<filename>

    ds_aux = xr.open_dataset(out_path, engine="h5netcdf", chunks="auto")
    # AUX often carries lat/lon too; ensure present
    #if not {"latitude","longitude"}.issubset(ds_aux):
    #    raise RuntimeError("AUX file missing latitude/longitude variables")

    # apply the SAME across-track cut to AUX
    if across_dim in ds_aux.dims:
        ds_aux = ds_aux.isel({across_dim: slice(0, across_max+1)})

    # --- bbox crop both to (W,S,E,N)
    W,S,E,N = bounding_box
    mask_ds   = (ds.latitude>=S) & (ds.latitude<=N) & (ds.longitude>=W) & (ds.longitude<=E)
    if not bool(mask_ds.any().compute()):   # dask-safe reduction to a Python bool
        return None
    ds = ds.where(mask_ds, drop=True)

    mask_aux  = (ds_aux.latitude>=S) & (ds_aux.latitude<=N) & (ds_aux.longitude>=W) & (ds_aux.longitude<=E)
    # build mask (still Dask at this point)
    mask_aux = (
        (ds_aux.latitude >= S) & (ds_aux.latitude <= N) &
        (ds_aux.longitude >= W) & (ds_aux.longitude <= E)
    )
    
    # turn into a NumPy-backed DataArray so boolean indexing is allowed
    mask_aux = mask_aux.compute()   # or .load()
    if not bool(mask_aux.any().compute()):
        return None
        
    # select only the variables that actually exist in your AUX
    aux_vars = [v for v in ("water_cloud_fraction", "waterfraction") if v in ds_aux.variables]
    
    # now this will work without the KeyError
    ds_aux_crop = ds_aux[aux_vars].where(mask_aux, drop=True)
    # try direct merge if shapes now match
    ok_shapes = (
        ds.sizes.get(along_dim) == ds_aux_crop.sizes.get(along_dim)
        and ds.sizes.get(across_dim) == ds_aux_crop.sizes.get(across_dim)
    )

    if ok_shapes:
        ds = xr.merge([ds, ds_aux_crop])
    else:
        # Fallback: nearest-neighbor remap AUX → L2 grid (about a few ms per granule)
        wcf_on_ds = _nn_remap_to_target_grid(
            ds.latitude, ds.longitude,
            ds_aux_crop.latitude, ds_aux_crop.longitude,
            ds_aux_crop["water_cloud_fraction"]
        )
        wf_on_ds = _nn_remap_to_target_grid(
            ds.latitude, ds.longitude,
            ds_aux_crop.latitude, ds_aux_crop.longitude,
            ds_aux_crop["waterfraction"]
        )
        ds = xr.merge([ds, wcf_on_ds, wf_on_ds])

    # close and cleanup
    ds_aux.close()
    try:
        out_path.unlink()
    except Exception:
        pass

    return ds

# %% [markdown]
# # Southern Ocean

# %%
bbox = (-170,-60,-120,-50)

results = earthaccess.search_data(
    short_name="PACE_HARP2_L2_CLOUD_GPC_NRT",
    bounding_box=bbox,
)
print(len(results))

paths = earthaccess.open(results)

er_RFT, ev_RFT, modefrac, er, ev, cdnc, lwp, tau, cth, ctt, ctp, lindex, lat, lon = gather_GPC(paths,bbox)
# Out:
# 584
# QUEUEING TASKS | :   0%|          | 0/584 [00:00<?, ?it/s]
# PROCESSING TASKS | :   0%|          | 0/584 [00:00<?, ?it/s]
# COLLECTING RESULTS | :   0%|          | 0/584 [00:00<?, ?it/s]
# PACE_OCI.20250701T012949.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250701T210958.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250701T224819.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250702T002640.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250702T020501.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250702T214510.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250702T232331.L1C.ANC.V3_0.5km.NRT.nc
# I had an error 7
# PACE_OCI.20250703T024013.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250703T204201.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250703T222022.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250703T235843.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250704T013704.L1C.ANC.V3_0.5km.NRT.nc

# %%
plot_GPC_LWP_Nd_hist('Southern Ocean Region', er_RFT, ev_RFT, modefrac, er, ev, cdnc, lwp, tau, cth, ctt, ctp, lindex, lat, lon, CC)

# %%
plot_GPC_L3maps('Southern Ocean Region', er_RFT, ev_RFT, modefrac, er, ev, cdnc, lwp, tau, cth, ctt, ctp, lindex, lat, lon, CC)

# %% [markdown]
# # SEP region

# %%
title='South-East Pacific Region'
bbox = (-110,-35,-70,-10)
#tspan = ("2025-09-29", "2025-09-30")

results = earthaccess.search_data(
    short_name="PACE_HARP2_L2_CLOUD_GPC_NRT",
    bounding_box=bbox,
    #temporal = tspan,
)
print(len(results))

paths = earthaccess.open(results)

er_RFT, ev_RFT, modefrac, er_RFT2, ev_RFT2, modefrac2, cdnc, lwp, cdnc2, lwp2, tau, lindex, lat, lon, lat2, lon2 = gather_GPC(paths,bbox)
# Out:
# 706
# QUEUEING TASKS | :   0%|          | 0/706 [00:00<?, ?it/s]
# PROCESSING TASKS | :   0%|          | 0/706 [00:00<?, ?it/s]
# COLLECTING RESULTS | :   0%|          | 0/706 [00:00<?, ?it/s]
# PACE_OCI.20250701T175813.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250701T180313.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250701T180813.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250701T193633.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250701T194133.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250701T194633.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250701T211454.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250701T211954.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250702T170004.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250702T170504.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250702T183325.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250702T183825.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250702T184325.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250702T201145.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250702T201645.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250702T202145.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250703T173015.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250703T173515.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250703T174015.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250703T190836.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250703T191336.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250703T191836.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250703T204657.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250703T205157.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250704T180527.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250704T181027.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250704T181527.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250704T194348.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250704T194848.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250704T195348.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250704T212209.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250704T212709.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250705T170218.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250705T170718.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250705T171218.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250705T184039.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250705T184539.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250705T185039.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250705T201900.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250705T202400.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250705T202900.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250706T173729.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250706T174229.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250706T174729.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250706T191550.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250706T192050.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250706T192550.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250706T205411.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250706T205911.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250707T181240.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250707T181740.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250707T182240.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250707T195101.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250707T195601.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250707T200101.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250707T212922.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250708T170930.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250708T171430.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250708T171930.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250708T184751.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250708T185251.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250708T185751.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250708T202612.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250708T203112.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250708T203612.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250709T174441.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250709T174941.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250709T175441.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250709T192302.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250709T192802.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250709T193302.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250709T210123.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250709T210623.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250710T181952.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250710T182452.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250710T182952.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250710T195812.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250710T200312.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250710T200812.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250710T213633.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250711T171641.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250711T172141.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250711T172641.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250711T185502.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250711T190002.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250711T190502.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250711T203323.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250711T203823.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250711T204323.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250712T175152.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250712T175652.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250712T180152.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250712T193012.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250712T193512.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250712T194012.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250712T210833.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250712T211333.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250713T165341.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250713T165841.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250713T182702.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250713T183202.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250713T183702.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250713T200523.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250713T201023.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250713T201523.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250714T172351.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250714T172851.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250714T173351.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250714T190212.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250714T190712.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250714T191212.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250714T204033.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250714T204533.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250714T205033.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250715T175901.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250715T180401.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250715T180901.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250715T193722.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250715T194222.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250715T194722.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250715T211543.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250715T212043.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250716T170050.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250716T170550.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250716T183411.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250716T183911.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250716T184411.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250716T201232.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250716T201732.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250716T202232.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250717T173100.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250717T173600.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250717T174100.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250717T190921.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250717T191421.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250717T191921.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250717T204742.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250717T205242.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250717T205742.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250718T180610.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250718T181110.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250718T181610.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250718T194430.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250718T194930.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250718T195430.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250718T212251.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250718T212751.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250719T170258.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250719T170758.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250719T171258.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250719T184119.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250719T184619.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250719T185119.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250719T201940.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250719T202440.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250719T202940.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250720T173808.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250720T174308.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250720T174808.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250720T191628.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250720T192128.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250720T192628.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250720T205449.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250720T205949.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250720T210449.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250721T181317.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250721T181817.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250721T182317.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250721T195138.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250721T195638.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250721T200138.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250721T212958.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250722T171005.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250722T171505.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250722T172005.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250722T184826.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250722T185326.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250722T185826.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250722T202647.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250722T203147.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250722T203647.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250723T174514.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250723T175014.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250723T175514.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250723T192335.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250723T192835.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250723T193335.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250723T210156.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250723T210656.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250723T211156.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250724T182023.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250724T182523.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250724T183023.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250724T195844.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250724T200344.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250724T200844.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250724T213705.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250725T171711.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250725T172211.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250725T172711.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250725T185532.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250725T190032.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250725T190532.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250725T203353.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250725T203853.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250725T204353.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250726T175220.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250726T175720.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250726T180220.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250726T193041.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250726T193541.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250726T194041.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250726T210901.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250726T211401.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250727T165408.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250727T165908.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250727T182729.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250727T183229.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250727T183729.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250727T200549.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250727T201049.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250727T201549.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250728T172415.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250728T172915.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250728T173415.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250728T190235.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250728T190735.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250728T191235.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250728T204056.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250728T204556.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250728T205056.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250729T175923.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250729T180423.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250729T180923.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250729T193743.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250729T194243.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250729T194743.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250729T211604.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250729T212104.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250730T170110.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250730T170610.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250730T183431.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250730T183931.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250730T184431.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250730T201251.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250730T201751.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250730T202251.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250731T173118.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250731T173618.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250731T174118.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250731T190939.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250731T191439.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250731T191939.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250731T204759.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250731T205259.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250731T205759.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250802T170813.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250802T171313.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250802T184133.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250802T184633.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250802T185133.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250802T201954.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250802T202454.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250802T202954.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250803T173820.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250803T174320.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250803T174820.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250803T191641.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250803T192141.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250803T192641.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250803T205502.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250803T210002.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250803T210502.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250804T195146.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250804T195646.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250804T200146.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250804T213007.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250804T213507.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250805T171512.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250805T172012.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250805T184833.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250805T185333.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250805T185833.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250805T202653.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250805T203153.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250805T203653.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250806T175019.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250806T175519.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250806T192840.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250806T193340.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250806T211200.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250807T165205.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250807T182026.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250807T182526.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250807T183026.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250807T195846.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250807T200346.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250807T200846.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250807T213707.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250808T172212.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250808T172712.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250808T185533.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250808T190033.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250808T190533.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250809T175719.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250809T180219.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250809T210900.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250809T211400.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250810T165405.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250810T165905.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250810T182725.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250810T183225.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250810T183725.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250810T200546.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250810T201046.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250810T201546.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250811T172909.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250811T173409.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250811T190229.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250811T190729.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250811T191229.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250811T204050.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250811T204550.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250811T205050.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250812T180415.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250812T180915.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250812T193735.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250812T194235.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250812T194735.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250812T211556.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250812T212056.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250813T170100.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250813T170600.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250813T183920.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250813T184420.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250813T201241.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250813T201741.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250813T202241.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250814T173605.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250814T174105.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250814T190926.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250814T191426.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250814T191926.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250814T204746.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250814T205246.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250814T205746.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250815T181111.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250815T181611.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250815T194431.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250815T194931.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250815T195431.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250815T212252.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250815T212752.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250816T170756.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250816T171256.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250816T184616.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250816T185116.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250816T201937.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250816T202437.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250816T202937.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250817T174301.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250817T174801.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250817T191621.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250817T192121.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250817T192621.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250817T205442.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250817T205942.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250817T210442.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250818T181808.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250818T182308.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250818T195128.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250818T195628.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250818T200128.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250818T212949.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250818T213449.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250819T171452.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250819T171952.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250819T185313.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250819T185813.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250819T203133.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250819T203633.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250820T174958.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250820T175458.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250820T192818.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250820T193318.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250820T210638.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250820T211138.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250821T165142.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250821T182502.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250821T183002.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250821T200323.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250821T200823.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250821T214143.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250823T211332.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250823T211832.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250824T165836.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250824T183156.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250824T183656.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250824T201016.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250824T201516.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250825T172840.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250825T173340.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250825T190701.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250825T191201.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250825T204521.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250825T205021.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250826T180345.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250826T180845.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250826T194205.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250826T194705.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250826T212025.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250827T170028.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250827T170528.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250827T183849.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250827T184349.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250827T201709.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250827T202209.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250828T173532.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250828T174032.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250828T191353.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250828T191853.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250828T205213.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250828T205713.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250829T181036.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250829T181536.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250829T194857.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250829T195357.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250829T212717.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250830T170720.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250830T171220.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250830T184540.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250830T185040.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250830T202400.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250830T202900.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250831T174223.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250831T174723.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250831T192044.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250831T192544.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250831T205904.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250831T210404.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250901T181729.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250901T182229.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250901T195549.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250901T200049.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250901T213410.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250902T171412.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250902T171912.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250902T185233.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250902T185733.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250902T203053.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250902T203553.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250903T174916.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250903T175416.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250903T192736.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250903T193236.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250903T210557.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250903T211057.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250904T165059.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250904T165559.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250904T182420.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250904T182920.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250904T183420.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250904T200240.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250904T200740.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250904T214100.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250905T172103.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250905T172603.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250905T173103.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250905T185923.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250905T190423.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250905T190923.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250905T203743.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250905T204243.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250906T175606.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250906T180106.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250906T180606.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250906T193426.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250906T193926.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250906T194426.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250906T211247.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250906T211747.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250907T165749.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250907T170249.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250907T183109.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250907T183609.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250907T184109.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250907T200930.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250907T201430.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250908T172748.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250908T173248.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250908T173748.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250908T190609.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250908T191109.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250908T191609.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250908T204429.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250908T204929.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250909T180251.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250909T180751.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250909T181251.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250909T194111.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250909T194611.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250909T195111.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250909T211932.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250909T212432.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250910T165933.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250910T170433.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250910T170933.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250910T183753.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250910T184253.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250910T184753.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250910T201614.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250910T202114.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250910T202614.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250911T173436.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250911T173936.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250911T174436.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250911T191256.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250911T191756.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250911T192256.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250911T205116.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250911T205616.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250912T180938.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250912T181438.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250912T181938.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250912T194758.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250912T195258.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250912T195758.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250912T212618.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250914T174622.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250914T191942.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250914T192442.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250914T192942.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250914T205803.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250914T210303.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250915T181621.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250915T182121.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250915T182621.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250915T195441.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250915T200441.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250915T213301.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250916T171302.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250916T171802.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250916T172302.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250916T185123.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250916T185623.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250916T203443.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250917T174804.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250917T175304.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250917T175804.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250917T192624.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250917T193124.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250917T193624.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250917T210444.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250917T210944.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250918T165445.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250918T182305.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250918T182805.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250918T183305.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250918T200125.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250918T200625.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250918T201125.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250919T171946.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250919T172446.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250919T172946.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250919T185807.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250919T203627.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250920T175448.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250920T175948.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250920T180448.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250920T193308.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250920T193808.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250920T194308.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250920T211128.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250920T211628.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250921T165629.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250921T170129.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250921T182949.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250921T183449.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250921T183949.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250921T200809.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250921T201309.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250921T201809.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250922T172630.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250922T173130.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250922T173630.L1C.ANC.V3_1.5km.NRT.nc
# PACE.20250922T190451.L1C.ANC.5km.nc
# PACE_OCI.20250922T190951.L1C.ANC.V3_1.5km.NRT.nc
# PACE.20250922T191451.L1C.ANC.5km.nc
# PACE_OCI.20250922T204311.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250922T204811.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250922T205311.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250923T180131.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250923T180631.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250923T181131.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250923T193952.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250923T194452.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250923T194952.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250923T211812.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250923T212312.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250924T170312.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250924T170812.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250924T183632.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250924T184132.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250924T184632.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250924T201452.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250924T201952.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250924T202452.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250925T173813.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250925T174313.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250925T191133.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250925T191633.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250925T192133.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250925T204953.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250925T205453.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250925T205953.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250926T180814.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250926T181314.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250926T181814.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250926T194634.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250926T195134.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250926T195634.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250926T212454.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250926T212954.L1C.ANC.V3_1.5km.NRT.nc
# PACE.20250927T170954.L1C.ANC.5km.nc
# PACE_OCI.20250927T171454.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250927T184314.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250927T184814.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250927T185314.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250927T202134.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250927T202634.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250927T203134.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250928T174454.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250928T174954.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250928T191815.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250928T192315.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250928T192815.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250928T205635.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250928T210135.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250928T210635.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250929T181455.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250929T181955.L1C.ANC.V3_1.5km.NRT.nc
# PACE.20250929T182455.L1C.ANC.5km.nc
# PACE_OCI.20250929T195315.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250929T195815.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250929T200315.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250929T213135.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250929T213635.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250930T171635.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250930T172135.L1C.ANC.V3_1.5km.NRT.nc
# PACE.20250930T184955.L1C.ANC.5km.nc
# PACE.20250930T185455.L1C.ANC.5km.nc
# PACE.20250930T185955.L1C.ANC.5km.nc
# PACE.20250930T202815.L1C.ANC.5km.nc
# PACE.20250930T203315.L1C.ANC.5km.nc
# PACE_OCI.20250930T203815.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20251001T175135.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20251001T175635.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20251001T192455.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20251001T192955.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20251001T193455.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20251001T210316.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20251001T210816.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20251001T211316.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20251002T165315.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20251002T182635.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20251002T183135.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20251002T195956.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20251002T200456.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20251002T200956.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20251003T172315.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20251003T172815.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20251003T185636.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20251003T190136.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20251003T190636.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20251003T203456.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20251003T203956.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20251003T204456.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20251004T175816.L1C.ANC.V3_1.5km.NRT.nc
# PACE.20251004T180316.L1C.ANC.5km.nc
# PACE_OCI.20251004T193136.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20251004T193636.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20251004T194136.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20251004T210956.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20251004T211456.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20251005T165455.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20251005T165955.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20251005T183315.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20251005T183815.L1C.ANC.V3_1.5km.NRT.nc
# PACE.20251005T200636.L1C.ANC.5km.nc
# PACE.20251005T201136.L1C.ANC.5km.nc
# PACE.20251005T201636.L1C.ANC.5km.nc
# PACE.20251006T172947.L1C.ANC.5km.nc
# PACE_OCI.20251006T173447.L1C.ANC.V3_1.5km.NRT.nc
# PACE.20251006T190307.L1C.ANC.5km.nc
# PACE.20251006T190807.L1C.ANC.5km.nc
# PACE.20251006T191307.L1C.ANC.5km.nc
# PACE_OCI.20251006T204127.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20251006T204627.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20251006T205127.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20251007T180446.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20251007T180946.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20251007T193806.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20251007T194306.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20251007T194806.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20251007T211626.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20251007T212126.L1C.ANC.V3_1.5km.NRT.nc

# %%
plot_GPC_LWP_Nd_hist(title, er_RFT, ev_RFT, modefrac, er_RFT2, ev_RFT2, modefrac2, cdnc, lwp, cdnc2, lwp2, tau, lindex, lat, lon, lat2, lon2)

# %%
xbins = np.logspace(np.log10(5),np.log10(1100),50) # <- make a range from 10**xmin to 10**xmax ## Selected to sample SEP 95%
ybins = np.logspace(np.log10(5),np.log10(500),50) # <- make a range from 10**ymin to 10**ymax ## Selected to sample SEP 95%
counts, xedge, yedge = np.histogram2d(cdnc, lwp, bins=(xbins, ybins))
counts2, xedge, yedge = np.histogram2d(cdnc2, lwp2, bins=(xbins, ybins))
sum_re_RFT,   _, _ = np.histogram2d(cdnc, lwp, bins=(xbins, ybins), weights=er_RFT)
sum_ve_RFT,   _, _ = np.histogram2d(cdnc, lwp, bins=(xbins, ybins), weights=ev_RFT)
sum_modefrac,   _, _ = np.histogram2d(cdnc, lwp, bins=(xbins, ybins), weights=modefrac)    
sum_re_RFT2,   _, _ = np.histogram2d(cdnc2, lwp2, bins=(xbins, ybins), weights=er_RFT2)
sum_ve_RFT2,   _, _ = np.histogram2d(cdnc2, lwp2, bins=(xbins, ybins), weights=ev_RFT2)
sum_modefrac2,   _, _ = np.histogram2d(cdnc2, lwp2, bins=(xbins, ybins), weights=modefrac2)    
#sum_tau,   _, _ = np.histogram2d(cdnc, lwp, bins=(xbins, ybins), weights=tau)
sum_tau_log,   _, _ = np.histogram2d(cdnc, lwp, bins=(xbins, ybins), weights=np.log10(tau))
sum_lindex,   _, _ = np.histogram2d(cdnc, lwp, bins=(xbins, ybins), weights=lindex)
sum_lon,   _, _ = np.histogram2d(cdnc, lwp, bins=(xbins, ybins), weights=np.abs(lon))
sum_lat,   _, _ = np.histogram2d(cdnc, lwp, bins=(xbins, ybins), weights=np.abs(lat))
sum_thin_frac,   _, _ = np.histogram2d(cdnc, lwp, bins=(xbins, ybins), weights=(tau<=3))


# Mean and (optional) standard deviation of z per bin
with np.errstate(divide='ignore', invalid='ignore'):
    #mean_re = sum_re / counts
    #mean_ve = sum_ve / counts
    mean_re_mode0 = sum_re_RFT / counts
    mean_ve_mode0 = sum_ve_RFT / counts
    mean_modefrac0 = sum_modefrac / counts
    mean_re_mode1 = sum_re_RFT2 / counts2
    mean_ve_mode1 = sum_ve_RFT2 / counts2
    mean_modefrac1 = sum_modefrac2 / counts2
    #mean_tau = sum_tau / counts
    mean_tau_log = 10**(sum_tau_log / counts)
    #mean_CTH = sum_CTH / counts
    mean_lindex = sum_lindex / counts
    mean_thin_frac = sum_thin_frac / counts
    mean_lon = sum_lon / counts
    mean_lat = sum_lat / counts
    #mean_CC_AU = 10**(sum_CC_AU / counts)
    #mean_CC_SC = 10**(sum_CC_SC / counts)
    #mean_rmse_bow = sum_rmse_bow / counts    
    #mean_corr_bow = sum_corr_bow / counts
    
counts_plt=counts/np.sum(counts)
counts_plt=counts_plt.T
counts_plt[counts_plt == 0] = np.nan

h_norm = counts/counts.sum(axis=1,keepdims=True)
h_norm=np.transpose(h_norm)
h_norm[h_norm == 0] = np.nan

hist_sorted = np.sort(counts.ravel())
cumulative_sum = np.cumsum(hist_sorted)
total_count = cumulative_sum[-1]
fig,ax = plt.subplots(1,2,figsize=(12, 5))

colors = plt.cm.turbo(np.linspace(0, 1, 9))
plt.rcParams['axes.prop_cycle'] = plt.cycler(color=colors)


for ind in range(10, 40,4):
    ax[0].stairs((mean_modefrac0[:,ind:ind+4]).mean(axis=1),edges=xedge,label=f'mean LWP={np.mean(yedge[ind:ind+5]).round()}')
#plt.set_xscale('log')
ax[0].set_xscale('log')
ax[0].set_xlabel("$N_d$ [cm$^{-3}$]")
ax[0].set_ylabel("Mode0 Fraction")
ax[0].set_xlim([20,500])
ax[0].set_ylim([0.7,0.95])
plt.legend()

for ind in range(15, 45,4):
    ax[1].stairs((counts_plt[:,ind:ind+3]).sum(axis=1),edges=xedge,label=f'mean LWP={np.mean(yedge[ind:ind+3]).round()}')
#plt.set_xscale('log')
ax[1].set_xscale('log')
ax[1].set_xlabel("$N_d$ [cm$^{-3}$]")
ax[1].set_ylabel("counts")
ax[1].set_xlim([20,500])
#ax[1].set_ylim([0.6,0.95])
plt.legend()
plt.show()
# Out:
# /tmp/ipykernel_292/1415990358.py:66: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()

# %%
plot_GPC_L3maps(title, er_RFT, ev_RFT, modefrac, er_RFT2, ev_RFT2, modefrac2, cdnc, lwp, cdnc2, lwp2, tau, lindex, lat, lon, lat2, lon2)

# %%
xbins = np.linspace(np.nanmin(lon),np.nanmax(lon),75) 
ybins = np.linspace(np.nanmin(lat),np.nanmax(lat),75) 
xbc=(xbins[0:-1]+xbins[1:])/2 #bin centers not edges
ybc=(ybins[0:-1]+ybins[1:])/2

counts, xedge, yedge = np.histogram2d(lon, lat, bins=(xbins, ybins))
counts2, xedge, yedge = np.histogram2d(lon2, lat2, bins=(xbins, ybins))

sum_re,   _, _ = np.histogram2d(lon, lat, bins=(xbins, ybins), weights=er_RFT)
sum_ve,   _, _ = np.histogram2d(lon, lat, bins=(xbins, ybins), weights=ev_RFT)
sum_thin_frac,   _, _ = np.histogram2d(lon, lat, bins=(xbins, ybins), weights=(tau<=3))
sum_lindex,   _, _ = np.histogram2d(lon, lat, bins=(xbins, ybins), weights=lindex)
sum_modefrac,   _, _ = np.histogram2d(lon, lat, bins=(xbins, ybins), weights=modefrac)
sum_re_RFT2,   _, _ = np.histogram2d(lon2, lat2, bins=(xbins, ybins), weights=er_RFT2)
sum_ve_RFT2,   _, _ = np.histogram2d(lon2, lat2, bins=(xbins, ybins), weights=ev_RFT2)
sum_modefrac1,   _, _ = np.histogram2d(lon2, lat2, bins=(xbins, ybins), weights=modefrac2)    
sum_Nd,   _, _ = np.histogram2d(lon, lat, bins=(xbins, ybins), weights=cdnc)

# Mean and (optional) standard deviation of z per bin
with np.errstate(divide='ignore', invalid='ignore'):
    mean_lindex = sum_lindex / counts
    mean_thin_frac = sum_thin_frac / counts
    mean_modefrac0 = sum_modefrac / counts
    mean_modefrac1 = sum_modefrac1 / counts2    
    mean_ve0 = sum_ve / counts
    mean_re0 = sum_re / counts
    mean_ve1 = sum_ve_RFT2 / counts2
    mean_re1 = sum_re_RFT2 / counts2
    mean_Nd = sum_Nd / counts2


[lon_g,lat_g]=np.meshgrid(xbc,ybc)
LM = ~vec_is_over_land(lat_g,lon_g)  # True = land, False = ocean

fig,ax = plt.subplots(1,1,figsize=(5,4))
mask = LM
im = ax.scatter(mean_thin_frac[mask], mean_ve0[mask],c=mean_modefrac1[mask], s=2, cmap='turbo')
cb = fig.colorbar(im)
cb.set_label('Mode Fraction 1')
ax.set_xlabel("Thin Cloud Fraction")
ax.set_ylabel("CEV MODE 0")
plt.show()

mask2 = (mask & ~np.isnan(mean_thin_frac) & ~np.isnan(mean_ve0))
corr=np.corrcoef(mean_thin_frac[mask2].ravel(),mean_ve0[mask2].ravel())
correlation=corr[1,0]
print(correlation)
print(corr)

fig,ax = plt.subplots(1,1,figsize=(5,4))
mask = LM
im = ax.scatter(mean_thin_frac[mask], mean_ve0[mask],c=mean_re1[mask], s=2, cmap='turbo', vmin=5, vmax=18)
cb = fig.colorbar(im)
cb.set_label('CER MODE 1')
ax.set_xlabel("Thin Cloud Fraction")
ax.set_ylabel("CEV MODE 0")
plt.show()


fig,ax = plt.subplots(1,1,figsize=(5,4))
mask=LM
im=ax.scatter(mean_re1[mask], mean_ve0[mask],c=mean_thin_frac[mask], s=2, cmap='turbo', vmin=0.1)
ax.set_xlabel("CER MODE 1")
ax.set_ylabel("CEV MODE 0")
plt.show()

mask2 = (mask & ~np.isnan(mean_re1) & ~np.isnan(mean_ve0))
corr=np.corrcoef(mean_re1[mask2].ravel(),mean_ve0[mask2].ravel())
correlation=corr[1,0]
print(correlation)
print(corr)


#NEXT LOOK AT CEV_0 correlation with CER_1 => the transition to secondary mode is through increasing droplet broadening until you start collisions
# Out:
# 0.6207977514102637
# [[1.         0.62079775]
#  [0.62079775 1.        ]]
# 0.7343940387059401
# [[1.         0.73439404]
#  [0.73439404 1.        ]]

# %%
# Generate some sample data
xb = np.linspace(4,25,100)
yb = np.linspace(0.01,0.1,100)

cmap=plt.colormaps['turbo']
cmap.set_bad('gray', alpha=1.0)

# Create the 2D histogram
plt.hist2d(mean_re1[mask2],mean_ve0[mask2],bins=[xb, yb], cmap=cmap, cmin=1) # bins controls the grid size, cmap sets the color map
plt.colorbar(label='Count') # Add a color bar to indicate counts
plt.xlabel('CER MODE 1')
plt.ylabel('CEV MODE 0')
plt.title('2D Histogram of X and Y')
plt.show()

# %%
ybins = np.linspace(np.nanmin(er),np.nanmax(er),50) 
xbins = np.linspace(np.nanmin(tau),np.nanmax(tau),50) 

counts, xedge, yedge = np.histogram2d(tau,er, bins=(xbins, ybins))
counts, xedge, yedge = np.histogram2d(tau,er, bins=(xbins, ybins))
sum_re,   _, _ = np.histogram2d(tau,er, bins=(xbins, ybins), weights=er)
sum_ve,   _, _ = np.histogram2d(tau,er, bins=(xbins, ybins), weights=ev)
#sum_re_RFT,   _, _ = np.histogram2d(tau,er, bins=(xbins, ybins), weights=er_RFT)
#sum_ve_RFT,   _, _ = np.histogram2d(tau,er, bins=(xbins, ybins), weights=ev_RFT)
sum_tau,   _, _ = np.histogram2d(tau,er, bins=(xbins, ybins), weights=tau)
sum_tau_log,   _, _ = np.histogram2d(tau,er, bins=(xbins, ybins), weights=np.log10(tau))
sum_LWP,   _, _ = np.histogram2d(tau,er, bins=(xbins, ybins), weights=lwp)
sum_Nd,   _, _ = np.histogram2d(tau,er, bins=(xbins, ybins), weights=cdnc)
sum_CTH,   _, _ = np.histogram2d(tau,er, bins=(xbins, ybins), weights=cth)
sum_lindex,   _, _ = np.histogram2d(tau,er, bins=(xbins, ybins), weights=lindex)
sum_lon,   _, _ = np.histogram2d(tau,er, bins=(xbins, ybins), weights=np.abs(lon))
sum_lat,   _, _ = np.histogram2d(tau,er, bins=(xbins, ybins), weights=np.abs(lat))
sum_thin_frac,   _, _ = np.histogram2d(tau,er, bins=(xbins, ybins), weights=(tau<=3))
sum_CC_AU,   _, _ = np.histogram2d(tau,er, bins=(xbins, ybins), weights=np.log10(-CC[0].magnitude))
sum_CC_SC,   _, _ = np.histogram2d(tau,er, bins=(xbins, ybins), weights=np.log10(-CC[1].magnitude))
sum_rmse_bow,   _, _ = np.histogram2d(tau,er, bins=(xbins, ybins), weights=rmse_bow)
sum_corr_bow,   _, _ = np.histogram2d(tau,er, bins=(xbins, ybins), weights=corr_bow)

# Mean and (optional) standard deviation of z per bin
with np.errstate(divide='ignore', invalid='ignore'):
    mean_re = sum_re / counts
    mean_ve = sum_ve / counts
    mean_re_RFT = sum_re_RFT / counts
    mean_ve_RFT = sum_ve_RFT / counts
    mean_tau = sum_tau / counts
    mean_tau_log = 10**(sum_tau_log / counts)
    mean_LWP = sum_LWP / counts
    mean_Nd = sum_Nd / counts
    mean_CTH = sum_CTH / counts
    mean_lindex = sum_lindex / counts
    mean_thin_frac = sum_thin_frac / counts
    mean_lon = sum_lon / counts
    mean_lat = sum_lat / counts
    mean_CC_AU = 10**(sum_CC_AU / counts)
    mean_CC_SC = 10**(sum_CC_SC / counts)
    mean_rmse_bow = sum_rmse_bow / counts    
    mean_corr_bow = sum_corr_bow / counts


h_norm = counts/np.nansum(counts)
h_norm=np.transpose(h_norm)
h_norm[h_norm == 0] = np.nan

fig,ax = plt.subplots(3,2,figsize=(11, 8))
cmap=plt.colormaps['turbo']
cmap.set_bad('gray', alpha=1.0)
plt.suptitle('SEP Microphysical Ret Grid')

titles={}
ims={}

titles[(0,0)] = 'Histogram'
ims[(0,0)] = ax[0,0].pcolormesh(xedge,yedge,h_norm,cmap=cmap,norm=LogNorm(vmin=np.nanmin(h_norm), vmax=np.nanmax(h_norm)))
titles[(0,1)] = 'Mean CEV'
ims[(0,1)] = ax[0,1].pcolormesh(xedge,yedge,mean_ve.T,cmap=cmap)#,norm=LogNorm(vmin=np.nanmin(h_norm), vmax=0.12))
titles[(1,0)] = 'Mean COT'
ims[(1,0)] = ax[1,0].pcolormesh(xedge,yedge,mean_lindex.T,cmap=cmap)
titles[(1,1)] = 'Mean CTH'
ims[(1,1)] = ax[1,1].pcolormesh(xedge,yedge,mean_CTH.T,cmap=cmap)#,vmax=0.25)#,norm=LogNorm(vmin=np.nanmin(h_norm), vmax=0.12))
titles[(2,0)] = 'Mean LWP'
ims[(2,0)] = ax[2,0].pcolormesh(xedge,yedge,mean_LWP,cmap=cmap)
titles[(2,1)] = 'Mean Nd'
ims[(2,1)] = ax[2,1].pcolormesh(xedge,yedge,mean_Nd.T,cmap=cmap)#,vmax=0.25)#,norm=LogNorm(vmin=np.nanmin(h_norm), vmax=0.12))


for i in range(3):
    for j in range(2):
        #ax[i,j].plot([15,100], [10,300], color='black', linestyle='--', linewidth=2, label='$r_e=15\,\mathrm{\mum}$')
        #ax[i,j].contour(xedge[:-1], yedge[:-1], counts.T, levels=[hist_levels], colors="white", linestyles="--", linewidths=1)# 95% interval
        #ax[i,j].contour(xedge[:-1], yedge[:-1], counts, levels=hist_levels[1], colors="white", linestyles="--", linewidths=2)

        #ax[i,j].set_yscale('log')
        #ax[i,j].set_xscale('log')
        ax[i,j].set_xlabel("COT")
        ax[i,j].set_ylabel("CER")
        ax[i,j].set_title(titles[i,j])
        #ax[i,j].set_aspect('equal', adjustable='box')
        fig.colorbar(ims[(i,j)],ax=ax[i,j])

plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[30], line 28
#      26 mean_re = sum_re / counts
#      27 mean_ve = sum_ve / counts
# ---> 28 mean_re_RFT = sum_re_RFT / counts
#      29 mean_ve_RFT = sum_ve_RFT / counts
#      30 mean_tau = sum_tau / counts
#
# NameError: name 'sum_re_RFT' is not defined

# %% [markdown]
# # NEP Region

# %%
bbox = (-140,-40,-120,-25)

results = earthaccess.search_data(
    short_name="PACE_HARP2_L2_CLOUD_GPC_NRT",
    bounding_box=bbox,
)
print(len(results))

paths = earthaccess.open(results)
# Out:
# 337
# QUEUEING TASKS | :   0%|          | 0/337 [00:00<?, ?it/s]
# PROCESSING TASKS | :   0%|          | 0/337 [00:00<?, ?it/s]
# COLLECTING RESULTS | :   0%|          | 0/337 [00:00<?, ?it/s]

# %%
er = []
er_RFT = []
ev = []
ev_RFT = []
cdnc = []
lwp = []
tau = []
lindex = []
cth = []
ctp = []
ctt = []
lat = []
lon = []
rmse_bow = []
corr_bow = []

count = 0
counterr = 0

for p in paths:
    try: 
        ds = open_L2_CLOUD_GPC(p,bbox)
        across_dim = ds.latitude.dims[-1]  # last dim of lat/vars is across-track
        ds = ds.isel({across_dim: slice(0, 311)})  # drop columns > 310 up front
        mask = ~np.isnan(ds.cloud_bow_droplet_effective_radius.data.flatten()) & ~np.isnan(ds.cloud_bow_droplet_effective_variance.data.flatten()) & ~np.isnan(ds.cloud_bow_droplet_number_concentration_adiabatic.data.flatten()) & ~np.isnan(ds.cloud_bow_liquid_water_path.data.flatten())        
        er = np.concatenate((er,ds.cloud_bow_droplet_effective_radius.data.flatten()[mask]))
        ev = np.concatenate((ev,ds.cloud_bow_droplet_effective_variance.data.flatten()[mask]))
        er_RFT = np.concatenate((er_RFT,ds.cloud_rft_droplet_effective_radius_mode_0.data.flatten()[mask]))
        ev_RFT = np.concatenate((ev_RFT,ds.cloud_rft_droplet_effective_variance_mode_0.data.flatten()[mask]))
        rmse_bow =  np.concatenate((rmse_bow,ds.cloud_bow_rms.data.flatten()[mask]))
        corr_bow =  np.concatenate((corr_bow,ds.cloud_bow_fit_correlation.data.flatten()[mask]))    
        cdnc = np.concatenate((cdnc,ds.cloud_bow_droplet_number_concentration_adiabatic.data.flatten()[mask]))
        lwp = np.concatenate((lwp,ds.cloud_bow_liquid_water_path.data.flatten()[mask]))
        tau = np.concatenate((tau,ds.cloud_optical_thickness.data.flatten()[mask]))
        cth = np.concatenate((cth,ds.cloud_top_altitude.data.flatten()[mask]))
        ctt = np.concatenate((ctt,ds.cloud_top_temperature.data.flatten()[mask]))
        ctp = np.concatenate((ctp,ds.cloud_top_pressure.data.flatten()[mask]))
        
        lindex = np.concatenate((lindex,ds.cloud_liquid_index.data.flatten()[mask]))
        
        lat = np.concatenate((lat,ds.latitude.data.flatten()[mask]))
        lon = np.concatenate((lon,ds.longitude.data.flatten()[mask]))
        
        print(ds.aux_file)
        del(ds)
    except:
        print('I had an error', count)
    count += 1

CC=CC_growth_rates_retrieval(er,ev,tau,ctt,ctp,Cw=0.0020, fad=0.7, Qext = 2.0)
# Out:
# PACE_OCI.20250701T211454.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250701T211954.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250701T225315.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250701T225815.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250702T215006.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250702T215506.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250702T232827.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250703T204657.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250703T205157.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250703T222518.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250703T223018.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250704T212209.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250704T212709.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250704T230030.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250704T230530.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250705T201900.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250705T202400.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250705T215720.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250705T220220.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250705T233541.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250706T205411.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250706T205911.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250706T223232.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250706T223732.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250707T212922.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250707T213422.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250707T230742.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250707T231242.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250708T202612.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250708T203112.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250708T220432.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250708T220932.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250708T234253.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250709T210123.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250709T210623.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250709T223943.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250709T224443.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250710T213633.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250710T214133.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250710T231454.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250710T231954.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250711T203323.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250711T203823.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250711T221144.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250711T221644.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250711T235004.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250712T210833.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250712T211333.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250712T224654.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250712T225154.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250713T214343.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250713T214843.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250713T232204.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250713T232704.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250714T204033.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250714T204533.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250714T221853.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250714T222353.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250715T211543.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250715T212043.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250715T225403.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250715T225903.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250716T201732.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250716T215053.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250716T215553.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250716T232913.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250717T204742.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250717T205242.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250717T222602.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250717T223102.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250718T212251.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250718T212751.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250718T230112.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250718T230612.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250719T201940.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250719T202440.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250719T215800.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250719T220300.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250719T233621.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250720T205449.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250720T205949.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250720T223310.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250720T223810.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250721T212958.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250721T213458.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250721T230819.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250721T231319.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250722T202647.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250722T203147.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250722T220507.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250722T221007.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250722T234328.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250723T210156.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250723T210656.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250723T224016.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250723T224516.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250724T213705.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250724T214205.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250724T231525.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250724T232025.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250725T203353.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250725T203853.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250725T221213.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250725T221713.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250725T235034.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250726T210901.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250726T211401.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250726T224722.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250726T225222.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250727T214410.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250727T214910.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250727T232229.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250727T232729.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250728T204056.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250728T204556.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250728T221916.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250728T222416.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250729T211604.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250729T212104.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250729T225424.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250729T225924.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250730T201751.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250730T215112.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250730T215612.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250730T232932.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250730T233432.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250731T204759.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250731T205259.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250731T222620.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250731T223120.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250801T230128.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250801T230628.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250802T201954.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250802T202454.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250802T215815.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250802T220315.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250802T233635.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250803T205502.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250803T210002.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250803T223322.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250803T223822.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250804T213007.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250804T213507.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250804T230827.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250804T231327.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250805T202653.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250805T203153.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250805T220514.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250805T221014.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250805T234334.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250806T224021.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250806T224521.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250807T213707.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250807T214207.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250807T231527.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250807T232027.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250808T221214.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250808T221714.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250809T210900.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250809T211400.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250809T224720.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250809T225220.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250810T214406.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250810T214906.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250810T232225.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250810T232725.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250811T204050.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250811T204550.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250811T221910.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250811T222410.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250812T211556.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250812T212056.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250812T225416.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250812T225916.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250813T201741.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250813T215101.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250813T215601.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250813T232922.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250813T233422.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250814T204746.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250814T205246.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250814T222607.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250814T223107.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250815T212252.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250815T212752.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250815T230112.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250815T230612.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250816T201937.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250816T202437.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250816T215757.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250816T220257.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250816T233617.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250816T234117.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250817T205442.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250817T205942.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250817T223302.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250817T223802.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250818T212949.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250818T213449.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250818T230809.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250818T231309.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250819T203133.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250819T220454.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250819T220954.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250819T234314.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250820T210638.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250820T223959.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250820T224459.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250821T213643.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250821T214143.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250821T231504.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250821T232004.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250823T211332.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250823T224653.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250823T225153.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250824T214337.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250824T214837.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250824T232157.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250824T232657.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250825T204521.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250825T221841.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250825T222341.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250826T212025.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250826T212525.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250826T225346.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250826T225846.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250827T201709.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250827T202209.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250827T215529.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250827T232850.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250827T233350.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250828T205213.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250828T205713.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250828T222533.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250828T223033.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250829T212717.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250829T213217.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250829T230037.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250829T230537.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250830T202400.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250830T202900.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250830T220221.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250830T220721.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250830T233541.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250830T234041.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250831T205904.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250831T210404.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250831T223224.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250831T223724.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250901T213410.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250901T213910.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250901T230730.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250901T231230.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250902T203053.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250902T203553.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250902T220913.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250902T221413.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250902T234234.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250902T234734.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250903T210557.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250903T211057.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250903T223917.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250903T224417.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250904T214100.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250904T214600.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250904T231920.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250905T203743.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250905T204243.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250905T221604.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250905T222104.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250906T211247.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250906T211747.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250906T225107.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250906T225607.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250907T214750.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250907T215250.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250907T232607.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250908T204429.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250908T204929.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250908T222249.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250908T222749.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250909T211932.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250909T212432.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250909T225752.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250909T230252.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250910T201614.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250910T202114.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250910T215434.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250910T215934.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250910T233254.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250911T205116.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250911T205616.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250911T222936.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250911T223436.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250912T212618.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250912T213118.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250912T230439.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250912T230939.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250913T220121.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250913T220621.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250913T233941.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250914T205803.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250914T210303.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250914T223623.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250914T224123.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250915T213301.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250915T213801.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250915T231621.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250916T203443.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250916T220803.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250916T221303.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250916T234623.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250917T210444.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250917T210944.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250917T224304.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250918T213946.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250918T214446.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250918T231806.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250919T203627.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250919T221447.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250919T221947.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250920T211128.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250920T211628.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250920T224948.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250920T225448.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250921T214629.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250921T215129.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250921T232450.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250921T232950.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250922T204311.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250922T204811.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250922T222131.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250922T222631.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250923T211812.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250923T212312.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250923T225632.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250923T230132.L1C.ANC.V3_1.5km.NRT.nc

# %%
xbins = np.logspace(np.log10(5),np.log10(1100),50) # <- make a range from 10**xmin to 10**xmax ## Selected to sample SEP 95%
ybins = np.logspace(np.log10(5),np.log10(500),50) # <- make a range from 10**ymin to 10**ymax ## Selected to sample SEP 95%
counts, xedge, yedge = np.histogram2d(cdnc, lwp, bins=(xbins, ybins))
sum_re,   _, _ = np.histogram2d(cdnc, lwp, bins=(xbins, ybins), weights=er)
sum_ve,   _, _ = np.histogram2d(cdnc, lwp, bins=(xbins, ybins), weights=ev)
sum_re_RFT,   _, _ = np.histogram2d(cdnc, lwp, bins=(xbins, ybins), weights=er_RFT)
sum_ve_RFT,   _, _ = np.histogram2d(cdnc, lwp, bins=(xbins, ybins), weights=ev_RFT)
sum_tau,   _, _ = np.histogram2d(cdnc, lwp, bins=(xbins, ybins), weights=tau)
sum_tau_log,   _, _ = np.histogram2d(cdnc, lwp, bins=(xbins, ybins), weights=np.log10(tau))
sum_CTH,   _, _ = np.histogram2d(cdnc, lwp, bins=(xbins, ybins), weights=cth)
sum_lindex,   _, _ = np.histogram2d(cdnc, lwp, bins=(xbins, ybins), weights=lindex)
sum_lon,   _, _ = np.histogram2d(cdnc, lwp, bins=(xbins, ybins), weights=np.abs(lon))
sum_lat,   _, _ = np.histogram2d(cdnc, lwp, bins=(xbins, ybins), weights=np.abs(lat))
sum_thin_frac,   _, _ = np.histogram2d(cdnc, lwp, bins=(xbins, ybins), weights=(tau<=3))
sum_CC_AU,   _, _ = np.histogram2d(cdnc, lwp, bins=(xbins, ybins), weights=-CC[0].magnitude)
sum_CC_SC,   _, _ = np.histogram2d(cdnc, lwp, bins=(xbins, ybins), weights=-CC[1].magnitude)


# Mean and (optional) standard deviation of z per bin
with np.errstate(divide='ignore', invalid='ignore'):
    mean_re = sum_re / counts
    mean_ve = sum_ve / counts
    mean_re_RFT = sum_re_RFT / counts
    mean_ve_RFT = sum_ve_RFT / counts
    mean_tau = sum_tau / counts
    mean_tau_log = 10**(sum_tau_log / counts)
    mean_CTH = sum_CTH / counts
    mean_lindex = sum_lindex / counts
    mean_thin_frac = sum_thin_frac / counts
    mean_lon = sum_lon / counts
    mean_lat = sum_lat / counts
    mean_CC_AU = sum_CC_AU / counts
    mean_CC_SC = sum_CC_SC / counts
    
counts_plt=counts/np.sum(counts)
counts_plt=counts_plt.T
counts_plt[counts_plt == 0] = np.nan

h_norm = counts/counts.sum(axis=1,keepdims=True)
h_norm=np.transpose(h_norm)
h_norm[h_norm == 0] = np.nan

hist_sorted = np.sort(counts.ravel())
cumulative_sum = np.cumsum(hist_sorted)
total_count = cumulative_sum[-1]
#hist_levels=np.zeros(3,dtype=np.float64)
#for i in range(3):
#    prob = chi2.cdf([3**2, 2**2, 1**2], df=2)
    
prob=0.95
hist_levels = hist_sorted[cumulative_sum >= total_count * (1 - prob)][0]

##############
fig,ax = plt.subplots(2,2,figsize=(11, 8))
plt.suptitle('NEP Region')

cmap=plt.colormaps['turbo']
cmap.set_bad('gray', alpha=1.0)
titles={}
ims={}

titles[(0,0)] = 'Histogram ($N_d$ bin norm)'
ims[(0,0)] = ax[0,0].pcolormesh(xedge,yedge,h_norm,cmap=cmap,vmax=0.06)#,norm=LogNorm(vmin=np.nanmin(h_norm), vmax=0.12))
titles[(0,1)] = 'Mean $r_e$ ($N_d$ bin norm)'
ims[(0,1)] = ax[0,1].pcolormesh(xedge,yedge,mean_re.T,cmap=cmap,vmax=40)#,norm=LogNorm(vmin=np.nanmin(h_norm), vmax=0.12))
titles[(1,0)] = 'Mean Longitude ($N_d$ bin norm)'
ims[(1,0)] = ax[1,0].pcolormesh(xedge,yedge,mean_lon.T,cmap=cmap)#,norm=LogNorm(vmin=np.nanmin(h_norm), vmax=0.12))
titles[(1,1)] = 'Mean $v_e$ ($N_d$ bin norm)'
ims[(1,1)] = ax[1,1].pcolormesh(xedge,yedge,mean_ve.T,cmap=cmap,vmax=0.25)#,norm=LogNorm(vmin=np.nanmin(h_norm), vmax=0.12))

for i in range(2):
    for j in range(2):
        ax[i,j].plot([15,100], [10,300], color='black', linewidth=2, label='$r_e=15\,\mathrm{\mum}$')
        ax[i,j].contour(xedge[:-1], yedge[:-1], counts.T, levels=[hist_levels], colors="white", linestyles="--", linewidths=1)# 95% interval
        #ax[i,j].contour(xedge[:-1], yedge[:-1], counts, levels=hist_levels[1], colors="white", linestyles="--", linewidths=2)

        ax[i,j].set_yscale('log')
        ax[i,j].set_xscale('log')
        ax[i,j].set_xlabel("$N_d$ [cm$^{-3}$]")
        ax[i,j].set_ylabel("LWP [g m$^{-2}$]")
        ax[i,j].set_title(titles[i,j])
        ax[i,j].set_aspect('equal', adjustable='box')
        fig.colorbar(ims[(i,j)],ax=ax[i,j])
plt.tight_layout()
plt.show()


#####################
fig,ax = plt.subplots(2,2,figsize=(11, 8))
plt.suptitle('NEP Region RFT variant')

cmap=plt.colormaps['turbo']
cmap.set_bad('gray', alpha=1.0)
titles={}
ims={}

titles[(0,0)] = 'Histogram ($N_d$ bin norm)'
ims[(0,0)] = ax[0,0].pcolormesh(xedge,yedge,h_norm,cmap=cmap,vmax=0.06)#,norm=LogNorm(vmin=np.nanmin(h_norm), vmax=0.12))
titles[(0,1)] = 'Mean $r_e$ RFT ($N_d$ bin norm)'
ims[(0,1)] = ax[0,1].pcolormesh(xedge,yedge,mean_re_RFT.T,cmap=cmap,vmax=40)#,norm=LogNorm(vmin=np.nanmin(h_norm), vmax=0.12))
titles[(1,0)] = 'Mean Latitude ($N_d$ bin norm)'
ims[(1,0)] = ax[1,0].pcolormesh(xedge,yedge,mean_lat.T,cmap=cmap)#,norm=LogNorm(vmin=np.nanmin(h_norm), vmax=0.12))
titles[(1,1)] = 'Mean $v_e$ RFT ($N_d$ bin norm)'
ims[(1,1)] = ax[1,1].pcolormesh(xedge,yedge,mean_ve_RFT.T,cmap=cmap,vmax=0.25)#,norm=LogNorm(vmin=np.nanmin(h_norm), vmax=0.12))

for i in range(2):
    for j in range(2):
        ax[i,j].plot([15,100], [10,300], color='black', linewidth=2, label='$r_e=15\,\mathrm{\mum}$')
        ax[i,j].contour(xedge[:-1], yedge[:-1], counts.T, levels=[hist_levels], colors="white", linestyles="--", linewidths=1)# 95% interval
        #ax[i,j].contour(xedge[:-1], yedge[:-1], counts, levels=hist_levels[1], colors="white", linestyles="--", linewidths=2)

        ax[i,j].set_yscale('log')
        ax[i,j].set_xscale('log')
        ax[i,j].set_xlabel("$N_d$ [cm$^{-3}$]")
        ax[i,j].set_ylabel("LWP [g m$^{-2}$]")
        ax[i,j].set_title(titles[i,j])
        ax[i,j].set_aspect('equal', adjustable='box')
        fig.colorbar(ims[(i,j)],ax=ax[i,j])


plt.tight_layout()
plt.show()

##############
fig,ax = plt.subplots(3,2,figsize=(11, 8))
cmap=plt.colormaps['turbo']
cmap.set_bad('gray', alpha=1.0)
plt.suptitle('NEP Region adv Diagnostics')

titles={}
ims={}

titles[(0,0)] = 'Mean CC Autoconversion rate ($N_d$ bin norm)'
ims[(0,0)] = ax[0,0].pcolormesh(xedge,yedge,mean_CC_AU.T,cmap=cmap,norm=LogNorm(vmin=1e-6, vmax=np.nanmax(np.stack([mean_CC_AU,mean_CC_SC]))))#norm=LogNorm(vmin=np.nanmin(np.stack([mean_CC_AU,mean_CC_SC])), vmax=np.nanmax(np.stack([mean_CC_AU,mean_CC_SC]))))
titles[(0,1)] = 'Mean COT(log)($N_d$ bin norm)'
ims[(0,1)] = ax[0,1].pcolormesh(xedge,yedge,mean_tau_log.T,cmap=cmap,vmax=60)#,norm=LogNorm(vmin=np.nanmin(h_norm), vmax=0.12))
titles[(1,0)] = 'Mean CC Self-Collection rate ($N_d$ bin norm)'
ims[(1,0)] = ax[1,0].pcolormesh(xedge,yedge,mean_CC_SC.T,cmap=cmap,norm=LogNorm(vmin=1e-6, vmax=np.nanmax(np.stack([mean_CC_AU,mean_CC_SC]))))
titles[(1,1)] = 'Mean CTH ($N_d$ bin norm)'
ims[(1,1)] = ax[1,1].pcolormesh(xedge,yedge,mean_CTH.T,cmap=cmap)#,vmax=0.25)#,norm=LogNorm(vmin=np.nanmin(h_norm), vmax=0.12))
titles[(2,0)] = 'Mean CC Sum ($N_d$ bin norm)'
ims[(2,0)] = ax[2,0].pcolormesh(xedge,yedge,mean_CC_AU.T+mean_CC_SC.T,cmap=cmap,norm=LogNorm(vmin=1e-6, vmax=np.nanmax(np.stack([mean_CC_AU,mean_CC_SC]))))
titles[(2,1)] = 'Mean Liq Index ($N_d$ bin norm)'
ims[(2,1)] = ax[2,1].pcolormesh(xedge,yedge,mean_lindex.T,cmap=cmap)#,vmax=0.25)#,norm=LogNorm(vmin=np.nanmin(h_norm), vmax=0.12))


for i in range(3):
    for j in range(2):
        ax[i,j].plot([15,100], [10,300], color='black', linestyle='--', linewidth=2, label='$r_e=15\,\mathrm{\mum}$')
        ax[i,j].contour(xedge[:-1], yedge[:-1], counts.T, levels=[hist_levels], colors="white", linestyles="--", linewidths=1)# 95% interval
        #ax[i,j].contour(xedge[:-1], yedge[:-1], counts, levels=hist_levels[1], colors="white", linestyles="--", linewidths=2)

        ax[i,j].set_yscale('log')
        ax[i,j].set_xscale('log')
        ax[i,j].set_xlabel("$N_d$ [cm$^{-3}$]")
        ax[i,j].set_ylabel("LWP [g m$^{-2}$]")
        ax[i,j].set_title(titles[i,j])
        ax[i,j].set_aspect('equal', adjustable='box')
        fig.colorbar(ims[(i,j)],ax=ax[i,j])



plt.tight_layout()
plt.show()

# %%
xbins = np.linspace(np.nanmin(lon),np.nanmax(lon),50) 
ybins = np.linspace(np.nanmin(lat),np.nanmax(lat),50) 

counts, xedge, yedge = np.histogram2d(lon, lat, bins=(xbins, ybins))
counts, xedge, yedge = np.histogram2d(lon, lat, bins=(xbins, ybins))
sum_re,   _, _ = np.histogram2d(lon, lat, bins=(xbins, ybins), weights=er)
sum_ve,   _, _ = np.histogram2d(lon, lat, bins=(xbins, ybins), weights=ev)
sum_re_RFT,   _, _ = np.histogram2d(lon, lat, bins=(xbins, ybins), weights=er_RFT)
sum_ve_RFT,   _, _ = np.histogram2d(lon, lat, bins=(xbins, ybins), weights=ev_RFT)
sum_tau,   _, _ = np.histogram2d(lon, lat, bins=(xbins, ybins), weights=tau)
sum_tau_log,   _, _ = np.histogram2d(lon, lat, bins=(xbins, ybins), weights=np.log10(tau))
sum_LWP,   _, _ = np.histogram2d(lon, lat, bins=(xbins, ybins), weights=lwp)
sum_Nd,   _, _ = np.histogram2d(lon, lat, bins=(xbins, ybins), weights=cdnc)
sum_CTH,   _, _ = np.histogram2d(lon, lat, bins=(xbins, ybins), weights=cth)
sum_lindex,   _, _ = np.histogram2d(lon, lat, bins=(xbins, ybins), weights=lindex)
sum_lon,   _, _ = np.histogram2d(lon, lat, bins=(xbins, ybins), weights=np.abs(lon))
sum_lat,   _, _ = np.histogram2d(lon, lat, bins=(xbins, ybins), weights=np.abs(lat))
sum_thin_frac,   _, _ = np.histogram2d(lon, lat, bins=(xbins, ybins), weights=(tau<=3))
sum_CC_AU,   _, _ = np.histogram2d(lon, lat, bins=(xbins, ybins), weights=np.log10(-CC[0].magnitude))
sum_CC_SC,   _, _ = np.histogram2d(lon, lat, bins=(xbins, ybins), weights=np.log10(-CC[1].magnitude))
sum_rmse_bow,   _, _ = np.histogram2d(lon, lat, bins=(xbins, ybins), weights=rmse_bow)
sum_corr_bow,   _, _ = np.histogram2d(lon, lat, bins=(xbins, ybins), weights=corr_bow)


# Mean and (optional) standard deviation of z per bin
with np.errstate(divide='ignore', invalid='ignore'):
    mean_re = sum_re / counts
    mean_ve = sum_ve / counts
    mean_re_RFT = sum_re_RFT / counts
    mean_ve_RFT = sum_ve_RFT / counts
    mean_tau = sum_tau / counts
    mean_tau_log = 10**(sum_tau_log / counts)
    mean_LWP = sum_LWP / counts
    mean_Nd = sum_Nd / counts
    mean_CTH = sum_CTH / counts
    mean_lindex = sum_lindex / counts
    mean_thin_frac = sum_thin_frac / counts
    mean_lon = sum_lon / counts
    mean_lat = sum_lat / counts
    mean_CC_AU = 10**(sum_CC_AU / counts)
    mean_CC_SC = 10**(sum_CC_SC / counts)
    mean_rmse_bow = sum_rmse_bow / counts    
    mean_corr_bow = sum_corr_bow / counts


xbc=(xbins[0:-1]+xbins[1:])/2 #bin centers not edges
ybc=(ybins[0:-1]+ybins[1:])/2
[lon_g,lat_g]=np.meshgrid(xbc,ybc)

LM = ~vec_is_over_land(lat_g,lon_g)  # True = land, False = ocean
plt.pcolormesh(LM)
plt.show()

fig,ax = plt.subplots(3,2,figsize=(8, 11))
cmap=plt.colormaps['turbo']
cmap.set_bad('gray', alpha=1.0)
plt.suptitle('NEP Regional Maps')

titles={}
ims={}

titles[(0,0)] = 'Mean CER'
ims[(0,0)] = ax[0,0].pcolormesh(xedge,yedge,np.where(LM, mean_re.T, np.nan),cmap=cmap)#norm=LogNorm(vmin=np.nanmin(np.stack([mean_CC_AU,mean_CC_SC])), vmax=np.nanmax(np.stack([mean_CC_AU,mean_CC_SC]))))
titles[(0,1)] = 'Mean CEV'
ims[(0,1)] = ax[0,1].pcolormesh(xedge,yedge,np.where(LM, mean_ve.T, np.nan),cmap=cmap)#,norm=LogNorm(vmin=np.nanmin(h_norm), vmax=0.12))
titles[(1,0)] = 'Mean COT'
ims[(1,0)] = ax[1,0].pcolormesh(xedge,yedge,np.where(LM, mean_tau_log.T, np.nan),cmap=cmap)
titles[(1,1)] = 'Thin CF (COT<3)'
ims[(1,1)] = ax[1,1].pcolormesh(xedge,yedge,np.where(LM, mean_thin_frac.T, np.nan),cmap=cmap)#,vmax=0.25)#,norm=LogNorm(vmin=np.nanmin(h_norm), vmax=0.12))
titles[(2,0)] = 'Mean LWP'
ims[(2,0)] = ax[2,0].pcolormesh(xedge,yedge,np.where(LM, mean_LWP.T, np.nan),cmap=cmap)
titles[(2,1)] = 'Mean Nd'
ims[(2,1)] = ax[2,1].pcolormesh(xedge,yedge,np.where(LM, mean_Nd.T, np.nan),cmap=cmap)#,vmax=0.25)#,norm=LogNorm(vmin=np.nanmin(h_norm), vmax=0.12))


for i in range(3):
    for j in range(2):
        #ax[i,j].plot([15,100], [10,300], color='black', linestyle='--', linewidth=2, label='$r_e=15\,\mathrm{\mum}$')
        #ax[i,j].contour(xedge[:-1], yedge[:-1], counts.T, levels=[hist_levels], colors="white", linestyles="--", linewidths=1)# 95% interval
        #ax[i,j].contour(xedge[:-1], yedge[:-1], counts, levels=hist_levels[1], colors="white", linestyles="--", linewidths=2)

        #ax[i,j].set_yscale('log')
        #ax[i,j].set_xscale('log')
        ax[i,j].set_xlabel("Longitude")
        ax[i,j].set_ylabel("Latitude")
        ax[i,j].set_title(titles[i,j])
        ax[i,j].set_aspect('equal', adjustable='box')
        fig.colorbar(ims[(i,j)],ax=ax[i,j])

plt.tight_layout()
plt.show()

fig,ax = plt.subplots(3,2,figsize=(8, 11))
cmap=plt.colormaps['turbo']
cmap.set_bad('gray', alpha=1.0)
plt.suptitle('NEP Regional Maps')

titles={}
ims={}

titles[(0,0)] = 'Mean CER'
ims[(0,0)] = ax[0,0].pcolormesh(xedge,yedge,np.where(LM, mean_re.T, np.nan),cmap=cmap)#norm=LogNorm(vmin=np.nanmin(np.stack([mean_CC_AU,mean_CC_SC])), vmax=np.nanmax(np.stack([mean_CC_AU,mean_CC_SC]))))
titles[(0,1)] = 'Mean CEV'
ims[(0,1)] = ax[0,1].pcolormesh(xedge,yedge,np.where(LM, mean_ve.T, np.nan),cmap=cmap)#,norm=LogNorm(vmin=np.nanmin(h_norm), vmax=0.12))
titles[(1,0)] = 'Mean Liq Index'
ims[(1,0)] = ax[1,0].pcolormesh(xedge,yedge,np.where(LM, mean_lindex.T, np.nan),cmap=cmap)
titles[(1,1)] = 'Thin CF (COT<3)'
ims[(1,1)] = ax[1,1].pcolormesh(xedge,yedge,np.where(LM, mean_thin_frac.T, np.nan),cmap=cmap)#,vmax=0.25)#,norm=LogNorm(vmin=np.nanmin(h_norm), vmax=0.12))
titles[(2,0)] = 'Mean rmse bow'
ims[(2,0)] = ax[2,0].pcolormesh(xedge,yedge,np.where(LM, mean_rmse_bow.T, np.nan),cmap=cmap)
titles[(2,1)] = 'Mean corr bow'
ims[(2,1)] = ax[2,1].pcolormesh(xedge,yedge,np.where(LM, mean_corr_bow.T, np.nan),cmap=cmap)#,vmax=0.25)#,norm=LogNorm(vmin=np.nanmin(h_norm), vmax=0.12))


for i in range(3):
    for j in range(2):
        #ax[i,j].plot([15,100], [10,300], color='black', linestyle='--', linewidth=2, label='$r_e=15\,\mathrm{\mum}$')
        #ax[i,j].contour(xedge[:-1], yedge[:-1], counts.T, levels=[hist_levels], colors="white", linestyles="--", linewidths=1)# 95% interval
        #ax[i,j].contour(xedge[:-1], yedge[:-1], counts, levels=hist_levels[1], colors="white", linestyles="--", linewidths=2)

        #ax[i,j].set_yscale('log')
        #ax[i,j].set_xscale('log')
        ax[i,j].set_xlabel("Longitude")
        ax[i,j].set_ylabel("Latitude")
        ax[i,j].set_title(titles[i,j])
        ax[i,j].set_aspect('equal', adjustable='box')
        fig.colorbar(ims[(i,j)],ax=ax[i,j])

plt.tight_layout()
plt.show()

# %%
fig,ax = plt.subplots(1,1,figsize=(5,4))
mask=LM
cmap=plt.colormaps['turbo']
ax.scatter(mean_thin_frac[mask], mean_ve[mask],c=mean_corr_bow[mask], s=2, cmap=cmap)
ax.set_xlabel("Thin Cloud Fraction")
ax.set_ylabel("CEV")
plt.show()

fig,ax = plt.subplots(1,1,figsize=(5,4))
mask=LM
ax.scatter(mean_rmse_bow[mask], mean_corr_bow[mask], s=2)
ax.set_xlabel("RMSE")
ax.set_ylabel("Correlation")
plt.show()

corr=np.corrcoef(mean_thin_frac[mask].ravel(),mean_ve[mask].ravel())
correlation=corr[1,0]
print(correlation)
# Out:
# 0.4389926443833222

# %% [markdown]
# # SEA Region

# %%
#bbox = (-110,-35,-70,-10)
bbox = (-20,-25,12,0)   #W,S,E,N = bounding_box


results = earthaccess.search_data(
    short_name="PACE_HARP2_L2_CLOUD_GPC_NRT",
    bounding_box=bbox,
)
print(len(results))

paths = earthaccess.open(results)
# Out:
# 468
# QUEUEING TASKS | :   0%|          | 0/468 [00:00<?, ?it/s]
# PROCESSING TASKS | :   0%|          | 0/468 [00:00<?, ?it/s]
# COLLECTING RESULTS | :   0%|          | 0/468 [00:00<?, ?it/s]

# %%
er = []
er_RFT = []
ev = []
ev_RFT = []
cdnc = []
lwp = []
tau = []
lindex = []
cth = []
ctp = []
ctt = []
lat = []
lon = []
rmse_bow = []
corr_bow = []

count = 0
counterr = 0

for p in paths:
    try: 
        ds = open_L2_CLOUD_GPC(p,bbox)
        across_dim = ds.latitude.dims[-1]  # last dim of lat/vars is across-track
        ds = ds.isel({across_dim: slice(0, 311)})  # drop columns > 310 up front
        mask = ~np.isnan(ds.cloud_bow_droplet_effective_radius.data.flatten()) & ~np.isnan(ds.cloud_bow_droplet_effective_variance.data.flatten()) & ~np.isnan(ds.cloud_bow_droplet_number_concentration_adiabatic.data.flatten()) & ~np.isnan(ds.cloud_bow_liquid_water_path.data.flatten())        
        er = np.concatenate((er,ds.cloud_bow_droplet_effective_radius.data.flatten()[mask]))
        ev = np.concatenate((ev,ds.cloud_bow_droplet_effective_variance.data.flatten()[mask]))
        er_RFT = np.concatenate((er_RFT,ds.cloud_rft_droplet_effective_radius_mode_0.data.flatten()[mask]))
        ev_RFT = np.concatenate((ev_RFT,ds.cloud_rft_droplet_effective_variance_mode_0.data.flatten()[mask]))
        rmse_bow =  np.concatenate((rmse_bow,ds.cloud_bow_rms.data.flatten()[mask]))
        corr_bow =  np.concatenate((corr_bow,ds.cloud_bow_fit_correlation.data.flatten()[mask]))    
        cdnc = np.concatenate((cdnc,ds.cloud_bow_droplet_number_concentration_adiabatic.data.flatten()[mask]))
        lwp = np.concatenate((lwp,ds.cloud_bow_liquid_water_path.data.flatten()[mask]))
        tau = np.concatenate((tau,ds.cloud_optical_thickness.data.flatten()[mask]))
        cth = np.concatenate((cth,ds.cloud_top_altitude.data.flatten()[mask]))
        ctt = np.concatenate((ctt,ds.cloud_top_temperature.data.flatten()[mask]))
        ctp = np.concatenate((ctp,ds.cloud_top_pressure.data.flatten()[mask]))
        
        lindex = np.concatenate((lindex,ds.cloud_liquid_index.data.flatten()[mask]))
        
        lat = np.concatenate((lat,ds.latitude.data.flatten()[mask]))
        lon = np.concatenate((lon,ds.longitude.data.flatten()[mask]))
        
        print(ds.aux_file)
        del(ds)
    except:
        print('I had an error', count)
    count += 1

CC=CC_growth_rates_retrieval(er,ev,tau,ctt,ctp,Cw=0.0020, fad=0.7, Qext = 2.0)
# Out:
# PACE_OCI.20250701T112950.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250701T113450.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250701T130810.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250701T131310.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250701T144631.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250701T145131.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250702T120502.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250702T121002.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250702T134322.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250702T134822.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250702T152143.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250703T124013.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250703T124513.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250703T141834.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250703T142334.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250704T113704.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250704T114204.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250704T131525.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250704T132025.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250704T145346.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250704T145846.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250705T121216.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250705T121716.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250705T135036.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250705T135536.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250705T152857.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250706T124727.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250706T125227.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250706T142548.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250706T143048.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250707T114417.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250707T114917.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250707T132238.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250707T132738.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250707T150059.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250707T150559.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250708T121928.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250708T122428.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250708T135749.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250708T140249.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250709T112118.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250709T125439.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250709T125939.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250709T143300.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250709T143800.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250710T132950.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250710T133450.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250710T150810.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250710T151310.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250711T122639.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250711T123139.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250711T140500.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250711T141000.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250712T112829.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250712T130150.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250712T130650.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250712T144010.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250712T144510.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250713T115839.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250713T120339.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250713T133700.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250713T134200.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250713T151521.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250714T123349.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250714T123849.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250714T141210.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250714T141710.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250715T113039.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250715T113539.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250715T130859.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250715T131359.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250715T144720.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250715T145220.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250716T120549.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250716T121049.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250716T134409.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250716T134909.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250716T152230.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250717T124058.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250717T124558.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250717T141919.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250717T142419.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250718T113747.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250718T114247.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250718T131608.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250718T132108.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250718T145428.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250718T145928.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250719T121257.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250719T121757.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250719T135117.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250719T135617.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250720T124806.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250720T125306.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250720T142627.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250720T143127.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250721T114455.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250721T114955.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250721T132315.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250721T132815.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250721T150136.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250721T150636.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250722T122004.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250722T122504.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250722T135824.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250722T140324.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250723T112152.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250723T125513.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250723T130013.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250723T143333.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250723T143833.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250724T115201.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250724T115701.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250724T133022.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250724T133522.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250724T150842.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250724T151342.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250725T122710.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250725T123210.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250725T140530.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250725T141030.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250726T112858.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250726T130218.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250726T130718.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250726T144039.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250726T144539.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250727T115907.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250727T120407.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250727T133727.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250727T134227.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250727T151547.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250728T123413.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250728T123913.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250728T141234.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250728T141734.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250729T113101.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250729T113601.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250729T130921.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250729T131421.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250729T144742.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250729T145242.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250730T120609.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250730T121109.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250730T134429.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250730T134929.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250730T152250.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250731T124117.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250731T124617.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250731T141937.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250731T142437.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250801T113804.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250801T114304.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250801T131624.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250801T132124.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250802T121312.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250802T121812.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250802T122312.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250802T135132.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250802T135632.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250803T124819.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250803T125319.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250803T125819.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250803T142639.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250803T143139.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250804T114504.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250804T115004.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250804T115504.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250804T132324.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250804T132824.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250804T133324.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250804T150145.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250804T150645.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250805T122011.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250805T122511.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250805T123011.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250805T135831.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250805T140331.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250806T112157.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250806T112657.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250806T125518.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250806T130018.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250806T130518.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250806T143338.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250806T143838.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250807T115204.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250807T115704.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250807T120204.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250807T133025.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250807T133525.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250807T134025.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250807T150845.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250807T151345.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250808T122711.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250808T123211.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250808T123711.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250808T140531.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250808T141031.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250809T112857.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250809T113357.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250809T130218.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250809T130718.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250809T131218.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250809T144038.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250809T144538.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250810T115904.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250810T120404.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250810T120904.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250810T133724.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250810T134224.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250810T134724.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250810T151544.L1C.ANC.V3_0.5km.NRT.nc
# PACE_OCI.20250811T123408.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250811T123908.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250811T124408.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250811T141228.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250811T141728.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250812T113053.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250812T113553.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250812T114053.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250812T130914.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250812T131414.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250812T131914.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250812T144734.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250812T145234.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250813T120559.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250813T121059.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250813T121559.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250813T134419.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250813T134919.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250813T135419.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250813T152240.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250814T124105.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250814T124605.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250814T125105.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250814T141925.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250814T142425.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250814T142925.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250815T113750.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250815T114250.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250815T114750.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250815T131610.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250815T132110.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250815T132610.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250815T145430.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250815T145930.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250816T121255.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250816T121755.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250816T122255.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250816T135115.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250816T135615.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250816T140115.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250817T124800.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250817T125300.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250817T125800.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250817T142620.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250817T143120.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250817T143620.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250818T114447.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250818T114947.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250818T115447.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250818T132307.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250818T132807.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250818T133307.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250818T150127.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250818T150627.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250819T121952.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250819T122452.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250819T122952.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250819T135812.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250819T140312.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250819T140812.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250820T112136.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250820T112636.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250820T125457.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250820T125957.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250820T130457.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250820T143317.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250820T143817.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250820T144317.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250821T115141.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250821T115641.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250821T120141.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250821T133002.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250821T133502.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250821T134002.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250821T150822.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250821T151322.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250822T122646.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250822T123146.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250822T123646.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250822T140506.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250822T141248.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250822T141506.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250824T115835.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250824T120335.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250824T120835.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250824T133655.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250824T134155.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250824T134655.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250824T151515.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250824T152015.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250825T123340.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250825T123840.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250825T124340.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250825T141200.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250825T141700.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250825T142200.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250826T113024.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250826T113524.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250826T114024.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250826T130844.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250826T131344.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250826T131844.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250826T144704.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250826T145204.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250826T145704.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250827T120528.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250827T121028.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250827T121528.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250827T134348.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250827T134848.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250827T135348.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250827T152208.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250828T124032.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250828T124532.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250828T125032.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250828T141852.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250828T142352.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250828T142852.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250829T114215.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250829T114715.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250829T131536.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250829T132036.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250829T132536.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250829T145356.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250829T145856.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250829T150356.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250830T121219.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250830T121719.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250830T122219.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250830T135039.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250830T135539.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250830T140039.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250831T111903.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250831T124723.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250831T125223.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250831T125723.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250831T142543.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250831T143043.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250831T143543.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250901T114908.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250901T115408.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250901T132228.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250901T132728.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250901T133228.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250901T150048.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250901T150548.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250902T122412.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250902T122912.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250902T135732.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250902T140232.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250902T140732.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250903T112555.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250903T125415.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250903T125915.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250903T130415.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250903T143236.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250903T143736.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250903T144236.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250904T115559.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250904T120059.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250904T132919.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250904T133419.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250904T133919.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250904T150739.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250904T151239.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250905T123102.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250905T123602.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250905T140422.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250905T140922.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250905T141422.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250906T112745.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250906T113245.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250906T130106.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250906T130606.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250906T131106.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250906T143926.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250906T144426.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250906T144926.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250907T120249.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250907T120749.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250907T133609.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250907T134109.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250907T134609.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250907T151429.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250907T151929.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250908T123748.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250908T124248.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250908T141108.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250908T141608.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250908T142108.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250909T113431.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250909T113931.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250909T131251.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250909T131751.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250909T144611.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250909T145111.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250909T145611.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250910T120933.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250910T121433.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250910T134753.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250910T135253.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250910T152613.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250911T124435.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250911T124935.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250911T142255.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250911T142755.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250912T114118.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250912T114618.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250912T131938.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250912T132438.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250912T145758.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250912T150258.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250914T111802.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250914T125122.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250914T125622.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250914T142942.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250914T143442.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250915T114801.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250915T115301.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250915T132621.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250915T133121.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250916T122302.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250916T122802.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250916T140622.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250917T112444.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250917T125804.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250917T130304.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250917T143624.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250917T144124.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250918T115445.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250918T115945.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250918T133305.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250918T133805.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250918T151125.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250919T122946.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250919T123446.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250919T140806.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250919T141306.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250920T112628.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250920T113128.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250920T130448.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250920T144308.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250920T144808.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250921T120129.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250921T120629.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250921T134449.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250921T151808.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250922T123630.L1C.ANC.V3_1.5km.NRT.nc
# PACE.20250922T124130.L1C.ANC.5km.nc
# PACE.20250922T141450.L1C.ANC.5km.nc
# PACE_OCI.20250922T141950.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250923T113311.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250923T113811.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250923T131131.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250923T131631.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250923T144951.L1C.ANC.V3_1.5km.NRT.nc
# PACE_OCI.20250923T145451.L1C.ANC.V3_1.5km.NRT.nc

# %%
xbins = np.logspace(np.log10(5),np.log10(1100),50) # <- make a range from 10**xmin to 10**xmax ## Selected to sample SEP 95%
ybins = np.logspace(np.log10(5),np.log10(500),50) # <- make a range from 10**ymin to 10**ymax ## Selected to sample SEP 95%
counts, xedge, yedge = np.histogram2d(cdnc, lwp, bins=(xbins, ybins))
sum_re,   _, _ = np.histogram2d(cdnc, lwp, bins=(xbins, ybins), weights=er)
sum_ve,   _, _ = np.histogram2d(cdnc, lwp, bins=(xbins, ybins), weights=ev)
sum_re_RFT,   _, _ = np.histogram2d(cdnc, lwp, bins=(xbins, ybins), weights=er_RFT)
sum_ve_RFT,   _, _ = np.histogram2d(cdnc, lwp, bins=(xbins, ybins), weights=ev_RFT)
sum_tau,   _, _ = np.histogram2d(cdnc, lwp, bins=(xbins, ybins), weights=tau)
sum_tau_log,   _, _ = np.histogram2d(cdnc, lwp, bins=(xbins, ybins), weights=np.log10(tau))
sum_CTH,   _, _ = np.histogram2d(cdnc, lwp, bins=(xbins, ybins), weights=cth)
sum_lindex,   _, _ = np.histogram2d(cdnc, lwp, bins=(xbins, ybins), weights=lindex)
sum_lon,   _, _ = np.histogram2d(cdnc, lwp, bins=(xbins, ybins), weights=np.abs(lon))
sum_lat,   _, _ = np.histogram2d(cdnc, lwp, bins=(xbins, ybins), weights=np.abs(lat))
sum_thin_frac,   _, _ = np.histogram2d(cdnc, lwp, bins=(xbins, ybins), weights=(tau<=3))
sum_CC_AU,   _, _ = np.histogram2d(cdnc, lwp, bins=(xbins, ybins), weights=-CC[0].magnitude)
sum_CC_SC,   _, _ = np.histogram2d(cdnc, lwp, bins=(xbins, ybins), weights=-CC[1].magnitude)


# Mean and (optional) standard deviation of z per bin
with np.errstate(divide='ignore', invalid='ignore'):
    mean_re = sum_re / counts
    mean_ve = sum_ve / counts
    mean_re_RFT = sum_re_RFT / counts
    mean_ve_RFT = sum_ve_RFT / counts
    mean_tau = sum_tau / counts
    mean_tau_log = 10**(sum_tau_log / counts)
    mean_CTH = sum_CTH / counts
    mean_lindex = sum_lindex / counts
    mean_thin_frac = sum_thin_frac / counts
    mean_lon = sum_lon / counts
    mean_lat = sum_lat / counts
    mean_CC_AU = sum_CC_AU / counts
    mean_CC_SC = sum_CC_SC / counts
    
counts_plt=counts/np.sum(counts)
counts_plt=counts_plt.T
counts_plt[counts_plt == 0] = np.nan

h_norm = counts/counts.sum(axis=1,keepdims=True)
h_norm=np.transpose(h_norm)
h_norm[h_norm == 0] = np.nan

hist_sorted = np.sort(counts.ravel())
cumulative_sum = np.cumsum(hist_sorted)
total_count = cumulative_sum[-1]
#hist_levels=np.zeros(3,dtype=np.float64)
#for i in range(3):
#    prob = chi2.cdf([3**2, 2**2, 1**2], df=2)
    
prob=0.95
hist_levels = hist_sorted[cumulative_sum >= total_count * (1 - prob)][0]

##############
fig,ax = plt.subplots(2,2,figsize=(11, 8))
plt.suptitle('SEA Region')

cmap=plt.colormaps['turbo']
cmap.set_bad('gray', alpha=1.0)
titles={}
ims={}

titles[(0,0)] = 'Histogram ($N_d$ bin norm)'
ims[(0,0)] = ax[0,0].pcolormesh(xedge,yedge,h_norm,cmap=cmap,vmax=0.06)#,norm=LogNorm(vmin=np.nanmin(h_norm), vmax=0.12))
titles[(0,1)] = 'Mean $r_e$ ($N_d$ bin norm)'
ims[(0,1)] = ax[0,1].pcolormesh(xedge,yedge,mean_re.T,cmap=cmap,vmax=40)#,norm=LogNorm(vmin=np.nanmin(h_norm), vmax=0.12))
titles[(1,0)] = 'Mean Longitude ($N_d$ bin norm)'
ims[(1,0)] = ax[1,0].pcolormesh(xedge,yedge,mean_lon.T,cmap=cmap)#,norm=LogNorm(vmin=np.nanmin(h_norm), vmax=0.12))
titles[(1,1)] = 'Mean $v_e$ ($N_d$ bin norm)'
ims[(1,1)] = ax[1,1].pcolormesh(xedge,yedge,mean_ve.T,cmap=cmap,vmax=0.25)#,norm=LogNorm(vmin=np.nanmin(h_norm), vmax=0.12))

for i in range(2):
    for j in range(2):
        ax[i,j].plot([15,100], [10,300], color='black', linewidth=2, label='$r_e=15\,\mathrm{\mum}$')
        ax[i,j].contour(xedge[:-1], yedge[:-1], counts.T, levels=[hist_levels], colors="white", linestyles="--", linewidths=1)# 95% interval
        #ax[i,j].contour(xedge[:-1], yedge[:-1], counts, levels=hist_levels[1], colors="white", linestyles="--", linewidths=2)

        ax[i,j].set_yscale('log')
        ax[i,j].set_xscale('log')
        ax[i,j].set_xlabel("$N_d$ [cm$^{-3}$]")
        ax[i,j].set_ylabel("LWP [g m$^{-2}$]")
        ax[i,j].set_title(titles[i,j])
        ax[i,j].set_aspect('equal', adjustable='box')
        fig.colorbar(ims[(i,j)],ax=ax[i,j])
plt.tight_layout()
plt.show()


#####################
fig,ax = plt.subplots(2,2,figsize=(11, 8))
plt.suptitle('SEA Region RFT variant')

cmap=plt.colormaps['turbo']
cmap.set_bad('gray', alpha=1.0)
titles={}
ims={}

titles[(0,0)] = 'Histogram ($N_d$ bin norm)'
ims[(0,0)] = ax[0,0].pcolormesh(xedge,yedge,h_norm,cmap=cmap,vmax=0.06)#,norm=LogNorm(vmin=np.nanmin(h_norm), vmax=0.12))
titles[(0,1)] = 'Mean $r_e$ RFT ($N_d$ bin norm)'
ims[(0,1)] = ax[0,1].pcolormesh(xedge,yedge,mean_re_RFT.T,cmap=cmap,vmax=40)#,norm=LogNorm(vmin=np.nanmin(h_norm), vmax=0.12))
titles[(1,0)] = 'Mean Latitude ($N_d$ bin norm)'
ims[(1,0)] = ax[1,0].pcolormesh(xedge,yedge,mean_lat.T,cmap=cmap)#,norm=LogNorm(vmin=np.nanmin(h_norm), vmax=0.12))
titles[(1,1)] = 'Mean $v_e$ RFT ($N_d$ bin norm)'
ims[(1,1)] = ax[1,1].pcolormesh(xedge,yedge,mean_ve_RFT.T,cmap=cmap,vmax=0.25)#,norm=LogNorm(vmin=np.nanmin(h_norm), vmax=0.12))

for i in range(2):
    for j in range(2):
        ax[i,j].plot([15,100], [10,300], color='black', linewidth=2, label='$r_e=15\,\mathrm{\mum}$')
        ax[i,j].contour(xedge[:-1], yedge[:-1], counts.T, levels=[hist_levels], colors="white", linestyles="--", linewidths=1)# 95% interval
        #ax[i,j].contour(xedge[:-1], yedge[:-1], counts, levels=hist_levels[1], colors="white", linestyles="--", linewidths=2)

        ax[i,j].set_yscale('log')
        ax[i,j].set_xscale('log')
        ax[i,j].set_xlabel("$N_d$ [cm$^{-3}$]")
        ax[i,j].set_ylabel("LWP [g m$^{-2}$]")
        ax[i,j].set_title(titles[i,j])
        ax[i,j].set_aspect('equal', adjustable='box')
        fig.colorbar(ims[(i,j)],ax=ax[i,j])


plt.tight_layout()
plt.show()

##############
fig,ax = plt.subplots(3,2,figsize=(11, 8))
cmap=plt.colormaps['turbo']
cmap.set_bad('gray', alpha=1.0)
plt.suptitle('SEA Region adv Diagnostics')

titles={}
ims={}

titles[(0,0)] = 'Mean CC Autoconversion rate ($N_d$ bin norm)'
ims[(0,0)] = ax[0,0].pcolormesh(xedge,yedge,mean_CC_AU.T,cmap=cmap,norm=LogNorm(vmin=1e-6, vmax=np.nanmax(np.stack([mean_CC_AU,mean_CC_SC]))))#norm=LogNorm(vmin=np.nanmin(np.stack([mean_CC_AU,mean_CC_SC])), vmax=np.nanmax(np.stack([mean_CC_AU,mean_CC_SC]))))
titles[(0,1)] = 'Mean COT(log)($N_d$ bin norm)'
ims[(0,1)] = ax[0,1].pcolormesh(xedge,yedge,mean_tau_log.T,cmap=cmap,vmax=60)#,norm=LogNorm(vmin=np.nanmin(h_norm), vmax=0.12))
titles[(1,0)] = 'Mean CC Self-Collection rate ($N_d$ bin norm)'
ims[(1,0)] = ax[1,0].pcolormesh(xedge,yedge,mean_CC_SC.T,cmap=cmap,norm=LogNorm(vmin=1e-6, vmax=np.nanmax(np.stack([mean_CC_AU,mean_CC_SC]))))
titles[(1,1)] = 'Mean CTH ($N_d$ bin norm)'
ims[(1,1)] = ax[1,1].pcolormesh(xedge,yedge,mean_CTH.T,cmap=cmap)#,vmax=0.25)#,norm=LogNorm(vmin=np.nanmin(h_norm), vmax=0.12))
titles[(2,0)] = 'Mean CC Sum ($N_d$ bin norm)'
ims[(2,0)] = ax[2,0].pcolormesh(xedge,yedge,mean_CC_AU.T+mean_CC_SC.T,cmap=cmap,norm=LogNorm(vmin=1e-6, vmax=np.nanmax(np.stack([mean_CC_AU,mean_CC_SC]))))
titles[(2,1)] = 'Mean Liq Index ($N_d$ bin norm)'
ims[(2,1)] = ax[2,1].pcolormesh(xedge,yedge,mean_lindex.T,cmap=cmap)#,vmax=0.25)#,norm=LogNorm(vmin=np.nanmin(h_norm), vmax=0.12))


for i in range(3):
    for j in range(2):
        ax[i,j].plot([15,100], [10,300], color='black', linestyle='--', linewidth=2, label='$r_e=15\,\mathrm{\mum}$')
        ax[i,j].contour(xedge[:-1], yedge[:-1], counts.T, levels=[hist_levels], colors="white", linestyles="--", linewidths=1)# 95% interval
        #ax[i,j].contour(xedge[:-1], yedge[:-1], counts, levels=hist_levels[1], colors="white", linestyles="--", linewidths=2)

        ax[i,j].set_yscale('log')
        ax[i,j].set_xscale('log')
        ax[i,j].set_xlabel("$N_d$ [cm$^{-3}$]")
        ax[i,j].set_ylabel("LWP [g m$^{-2}$]")
        ax[i,j].set_title(titles[i,j])
        ax[i,j].set_aspect('equal', adjustable='box')
        fig.colorbar(ims[(i,j)],ax=ax[i,j])



plt.tight_layout()
plt.show()

# %%
xbins = np.linspace(np.nanmin(lon),np.nanmax(lon),50) 
ybins = np.linspace(np.nanmin(lat),np.nanmax(lat),50) 

counts, xedge, yedge = np.histogram2d(lon, lat, bins=(xbins, ybins))
counts, xedge, yedge = np.histogram2d(lon, lat, bins=(xbins, ybins))
sum_re,   _, _ = np.histogram2d(lon, lat, bins=(xbins, ybins), weights=er)
sum_ve,   _, _ = np.histogram2d(lon, lat, bins=(xbins, ybins), weights=ev)
sum_re_RFT,   _, _ = np.histogram2d(lon, lat, bins=(xbins, ybins), weights=er_RFT)
sum_ve_RFT,   _, _ = np.histogram2d(lon, lat, bins=(xbins, ybins), weights=ev_RFT)
sum_tau,   _, _ = np.histogram2d(lon, lat, bins=(xbins, ybins), weights=tau)
sum_tau_log,   _, _ = np.histogram2d(lon, lat, bins=(xbins, ybins), weights=np.log10(tau))
sum_LWP,   _, _ = np.histogram2d(lon, lat, bins=(xbins, ybins), weights=lwp)
sum_Nd,   _, _ = np.histogram2d(lon, lat, bins=(xbins, ybins), weights=cdnc)
sum_CTH,   _, _ = np.histogram2d(lon, lat, bins=(xbins, ybins), weights=cth)
sum_lindex,   _, _ = np.histogram2d(lon, lat, bins=(xbins, ybins), weights=lindex)
sum_lon,   _, _ = np.histogram2d(lon, lat, bins=(xbins, ybins), weights=np.abs(lon))
sum_lat,   _, _ = np.histogram2d(lon, lat, bins=(xbins, ybins), weights=np.abs(lat))
sum_thin_frac,   _, _ = np.histogram2d(lon, lat, bins=(xbins, ybins), weights=(tau<=3))
sum_CC_AU,   _, _ = np.histogram2d(lon, lat, bins=(xbins, ybins), weights=np.log10(-CC[0].magnitude))
sum_CC_SC,   _, _ = np.histogram2d(lon, lat, bins=(xbins, ybins), weights=np.log10(-CC[1].magnitude))
sum_rmse_bow,   _, _ = np.histogram2d(lon, lat, bins=(xbins, ybins), weights=rmse_bow)
sum_corr_bow,   _, _ = np.histogram2d(lon, lat, bins=(xbins, ybins), weights=corr_bow)


# Mean and (optional) standard deviation of z per bin
with np.errstate(divide='ignore', invalid='ignore'):
    mean_re = sum_re / counts
    mean_ve = sum_ve / counts
    mean_re_RFT = sum_re_RFT / counts
    mean_ve_RFT = sum_ve_RFT / counts
    mean_tau = sum_tau / counts
    mean_tau_log = 10**(sum_tau_log / counts)
    mean_LWP = sum_LWP / counts
    mean_Nd = sum_Nd / counts
    mean_CTH = sum_CTH / counts
    mean_lindex = sum_lindex / counts
    mean_thin_frac = sum_thin_frac / counts
    mean_lon = sum_lon / counts
    mean_lat = sum_lat / counts
    mean_CC_AU = 10**(sum_CC_AU / counts)
    mean_CC_SC = 10**(sum_CC_SC / counts)
    mean_rmse_bow = sum_rmse_bow / counts    
    mean_corr_bow = sum_corr_bow / counts


xbc=(xbins[0:-1]+xbins[1:])/2 #bin centers not edges
ybc=(ybins[0:-1]+ybins[1:])/2
[lon_g,lat_g]=np.meshgrid(xbc,ybc)

LM = ~vec_is_over_land(lat_g,lon_g)  # True = land, False = ocean
plt.pcolormesh(LM)
plt.show()

fig,ax = plt.subplots(3,2,figsize=(8, 11))
cmap=plt.colormaps['turbo']
cmap.set_bad('gray', alpha=1.0)
plt.suptitle('SEA Regional Maps')

titles={}
ims={}

titles[(0,0)] = 'Mean CER'
ims[(0,0)] = ax[0,0].pcolormesh(xedge,yedge,np.where(LM, mean_re.T, np.nan),cmap=cmap)#norm=LogNorm(vmin=np.nanmin(np.stack([mean_CC_AU,mean_CC_SC])), vmax=np.nanmax(np.stack([mean_CC_AU,mean_CC_SC]))))
titles[(0,1)] = 'Mean CEV'
ims[(0,1)] = ax[0,1].pcolormesh(xedge,yedge,np.where(LM, mean_ve.T, np.nan),cmap=cmap)#,norm=LogNorm(vmin=np.nanmin(h_norm), vmax=0.12))
titles[(1,0)] = 'Mean COT'
ims[(1,0)] = ax[1,0].pcolormesh(xedge,yedge,np.where(LM, mean_tau_log.T, np.nan),cmap=cmap)
titles[(1,1)] = 'Thin CF (COT<3)'
ims[(1,1)] = ax[1,1].pcolormesh(xedge,yedge,np.where(LM, mean_thin_frac.T, np.nan),cmap=cmap)#,vmax=0.25)#,norm=LogNorm(vmin=np.nanmin(h_norm), vmax=0.12))
titles[(2,0)] = 'Mean LWP'
ims[(2,0)] = ax[2,0].pcolormesh(xedge,yedge,np.where(LM, mean_LWP.T, np.nan),cmap=cmap)
titles[(2,1)] = 'Mean Nd'
ims[(2,1)] = ax[2,1].pcolormesh(xedge,yedge,np.where(LM, mean_Nd.T, np.nan),cmap=cmap)#,vmax=0.25)#,norm=LogNorm(vmin=np.nanmin(h_norm), vmax=0.12))


for i in range(3):
    for j in range(2):
        #ax[i,j].plot([15,100], [10,300], color='black', linestyle='--', linewidth=2, label='$r_e=15\,\mathrm{\mum}$')
        #ax[i,j].contour(xedge[:-1], yedge[:-1], counts.T, levels=[hist_levels], colors="white", linestyles="--", linewidths=1)# 95% interval
        #ax[i,j].contour(xedge[:-1], yedge[:-1], counts, levels=hist_levels[1], colors="white", linestyles="--", linewidths=2)

        #ax[i,j].set_yscale('log')
        #ax[i,j].set_xscale('log')
        ax[i,j].set_xlabel("Longitude")
        ax[i,j].set_ylabel("Latitude")
        ax[i,j].set_title(titles[i,j])
        ax[i,j].set_aspect('equal', adjustable='box')
        fig.colorbar(ims[(i,j)],ax=ax[i,j])

plt.tight_layout()
plt.show()

fig,ax = plt.subplots(3,2,figsize=(8, 11))
cmap=plt.colormaps['turbo']
cmap.set_bad('gray', alpha=1.0)
plt.suptitle('SEA Regional Maps')

titles={}
ims={}

titles[(0,0)] = 'Mean CER'
ims[(0,0)] = ax[0,0].pcolormesh(xedge,yedge,np.where(LM, mean_re.T, np.nan),cmap=cmap)#norm=LogNorm(vmin=np.nanmin(np.stack([mean_CC_AU,mean_CC_SC])), vmax=np.nanmax(np.stack([mean_CC_AU,mean_CC_SC]))))
titles[(0,1)] = 'Mean CEV'
ims[(0,1)] = ax[0,1].pcolormesh(xedge,yedge,np.where(LM, mean_ve.T, np.nan),cmap=cmap)#,norm=LogNorm(vmin=np.nanmin(h_norm), vmax=0.12))
titles[(1,0)] = 'Mean COT'
ims[(1,0)] = ax[1,0].pcolormesh(xedge,yedge,np.where(LM, mean_lindex.T, np.nan),cmap=cmap)
titles[(1,1)] = 'Thin CF (COT<3)'
ims[(1,1)] = ax[1,1].pcolormesh(xedge,yedge,np.where(LM, mean_thin_frac.T, np.nan),cmap=cmap)#,vmax=0.25)#,norm=LogNorm(vmin=np.nanmin(h_norm), vmax=0.12))
titles[(2,0)] = 'Mean rmse bow'
ims[(2,0)] = ax[2,0].pcolormesh(xedge,yedge,np.where(LM, mean_rmse_bow.T, np.nan),cmap=cmap)
titles[(2,1)] = 'Mean corr bow'
ims[(2,1)] = ax[2,1].pcolormesh(xedge,yedge,np.where(LM, mean_corr_bow.T, np.nan),cmap=cmap)#,vmax=0.25)#,norm=LogNorm(vmin=np.nanmin(h_norm), vmax=0.12))


for i in range(3):
    for j in range(2):
        #ax[i,j].plot([15,100], [10,300], color='black', linestyle='--', linewidth=2, label='$r_e=15\,\mathrm{\mum}$')
        #ax[i,j].contour(xedge[:-1], yedge[:-1], counts.T, levels=[hist_levels], colors="white", linestyles="--", linewidths=1)# 95% interval
        #ax[i,j].contour(xedge[:-1], yedge[:-1], counts, levels=hist_levels[1], colors="white", linestyles="--", linewidths=2)

        #ax[i,j].set_yscale('log')
        #ax[i,j].set_xscale('log')
        ax[i,j].set_xlabel("Longitude")
        ax[i,j].set_ylabel("Latitude")
        ax[i,j].set_title(titles[i,j])
        ax[i,j].set_aspect('equal', adjustable='box')
        fig.colorbar(ims[(i,j)],ax=ax[i,j])

plt.tight_layout()
plt.show()

# %%
fig,ax = plt.subplots(1,1,figsize=(5,4))
mask=LM
cmap=plt.colormaps['turbo']
ax.scatter(mean_thin_frac[mask], mean_ve[mask],c=mean_corr_bow[mask], s=2, cmap=cmap)
ax.set_xlabel("Thin Cloud Fraction")
ax.set_ylabel("CEV")
plt.show()

fig,ax = plt.subplots(1,1,figsize=(5,4))
mask=LM
ax.scatter(mean_rmse_bow[mask], mean_corr_bow[mask], s=2)
ax.set_xlabel("RMSE")
ax.set_ylabel("Correlation")
plt.show()

corr=np.corrcoef(mean_thin_frac[mask].ravel(),mean_ve[mask].ravel())
correlation=corr[1,0]
print(correlation)
# Out:
# 0.577162368691877
